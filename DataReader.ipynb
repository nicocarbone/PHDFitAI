# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sim_tags = np.load('sim_tags_1.npy')
sim_results = np.load('sim_results_1.npy')
sim_irfs = np.load('sim_irfs_1.npy')
sim_randomsIRF = np.load('sim_randomsIRF_1.npy')
sim_randomsPHD = np.load('sim_randomsPHD_1.npy')

# %%
print(len(sim_tags))
print(sim_tags)
# Out:
# 1500
# [[1.66666667e-02 7.72972973e-01 2.50000000e+01 0.00000000e+00]
#  [1.66666667e-02 7.72972973e-01 2.50000000e+01 1.00000000e+00]
#  [1.42522523e-02 1.75315315e+00 2.50000000e+01 0.00000000e+00]
#  ...
#  [1.64144144e-02 1.80900901e+00 2.50000000e+01 1.00000000e+00]
#  [1.20540541e-02 1.32972973e+00 2.50000000e+01 0.00000000e+00]
#  [1.20540541e-02 1.32972973e+00 2.50000000e+01 1.00000000e+00]]

# %%
print(sim_randomsIRF)
# Out:
# [[5.3650000e+03 5.5470000e+03 6.2330000e+03 ... 1.7700000e+02
#   3.1000000e+01 9.9878500e+06]
#  [4.7060000e+03 4.9210000e+03 5.6840000e+03 ... 1.9200000e+02
#   1.0000000e+01 1.0084459e+07]
#  [4.7050000e+03 4.7580000e+03 5.3520000e+03 ... 1.9600000e+02
#   1.9000000e+01 1.0080591e+07]
#  ...
#  [4.3170000e+03 4.5540000e+03 5.1420000e+03 ... 2.0600000e+02
#   1.1000000e+01 1.0037719e+07]
#  [4.9350000e+03 5.1490000e+03 5.7630000e+03 ... 2.2900000e+02
#   2.0000000e+01 9.9657270e+06]
#  [5.1070000e+03 5.2810000e+03 5.8180000e+03 ... 2.0300000e+02
#   1.6000000e+01 1.0211754e+07]]

# %%
print(sim_randomsPHD)
# Out:
# [[1.06050400e-09 1.03939252e+00 2.14624697e+03 2.01003114e+08]
#  [1.07058637e-09 9.74596167e-01 1.87199143e+03 1.99865867e+08]
#  [1.11646727e-09 1.03438651e+00 2.06799183e+03 1.97942430e+08]
#  ...
#  [9.43770366e-10 9.96981923e-01 2.49389870e+03 1.98314744e+08]
#  [1.03267873e-09 1.00611450e+00 1.84250125e+03 1.98413937e+08]
#  [1.06912535e-09 1.01296026e+00 2.30882954e+03 2.00221714e+08]]

# %%
plt.plot(sim_irfs[0])
plt.plot(sim_irfs[10])
plt.plot(sim_irfs[59])
plt.plot(sim_irfs[122])
plt.plot(sim_irfs[289])

# %%
plt.plot(sim_results[0])
plt.plot(sim_results[10])
plt.plot(sim_results[59])
plt.plot(sim_results[122])
plt.plot(sim_results[289])

# %%
plt.plot(sim_results[10])
plt.yscale('log')
plt.show()

# %%
plt.plot(sim_irfs[10])
plt.yscale('log')
plt.show()

# %%
sample_irf = np.genfromtxt('sampleIRF_20mm_30mm.asc', skip_header=10, skip_footer=1)
plt.plot(sample_irf)
plt.yscale('log')
plt.show()
