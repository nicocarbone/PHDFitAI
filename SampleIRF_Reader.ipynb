# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sampleIRF = np.genfromtxt('sampleIRF.asc', skip_header=10, skip_footer=1)
print(np.shape(sampleIRF))
# Out:
# (4096,)

# %%
plt.plot(sampleIRF)
