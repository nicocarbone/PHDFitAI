# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import StepLR # Import StepLR scheduler
import matplotlib.pyplot as plt


class TurbidMediaDataset(Dataset):
    def __init__(self, histograms, irfs, ups, ua):
        self.histograms = histograms
        self.irfs = irfs
        self.ups = ups
        self.ua = ua

    def __len__(self):
        return len(self.histograms)

    def __getitem__(self, idx):
        histogram = torch.tensor(self.histograms[idx], dtype=torch.float32).unsqueeze(0) # Add channel dimension
        irf = torch.tensor(self.irfs[idx], dtype=torch.float32).unsqueeze(0) # Add channel dimension
        ups = torch.tensor(self.ups[idx], dtype=torch.float32)
        ua = torch.tensor(self.ua[idx], dtype=torch.float32)
        return histogram, irf, ups, ua

# Custom Exp Layer Module
class ExpLayer(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return torch.exp(x)

class OpticalPropertiesEstimator(nn.Module):
    def __init__(self, config): # Config dictionary as input
        super(OpticalPropertiesEstimator, self).__init__()
        self.config = config # Store config

        # CNN branch for Histogram
        hist_cnn_layers = []
        in_channels = 1 # Input channels for the first CNN layer
        cnn_filters_hist = config.get('cnn_filters_hist', [16, 32, 64]) # Convolutional neural network filter sizes
        kernel_size_cnn = config.get('kernel_size_cnn', 3) # Convolutional kernel size
        pool_size_cnn = config.get('pool_size_cnn', 2) # Pooling size
        padding_cnn = config.get('padding_cnn', 1) # Padding size
        use_batchnorm_cnn = config.get('use_batchnorm_cnn', True) # Configurable batch norm

        for out_channels in cnn_filters_hist:
            hist_cnn_layers.append(nn.Conv1d(in_channels, out_channels, kernel_size=kernel_size_cnn, padding=padding_cnn)) # 1D Convolutional layer
            if use_batchnorm_cnn:
                hist_cnn_layers.append(nn.BatchNorm1d(out_channels)) # Batch norm layer
            hist_cnn_layers.append(nn.ReLU())  # ReLU activation
            hist_cnn_layers.append(nn.MaxPool1d(pool_size_cnn))  # Max pooling
            in_channels = out_channels
        self.hist_cnn = nn.Sequential(*hist_cnn_layers)

        # CNN branch for IRF (similar structure to hist_cnn)
        irf_cnn_layers = []
        in_channels = 1
        cnn_filters_irf = config.get('cnn_filters_irf', [16, 32, 64]) # Default filter sizes for IRF CNN
        for out_channels in cnn_filters_irf:
            irf_cnn_layers.append(nn.Conv1d(in_channels, out_channels, kernel_size=kernel_size_cnn, padding=padding_cnn)) # 1D Convolutional layer
            if use_batchnorm_cnn:
                irf_cnn_layers.append(nn.BatchNorm1d(out_channels)) # Batch norm layer
            irf_cnn_layers.append(nn.ReLU()) # ReLU activation
            irf_cnn_layers.append(nn.MaxPool1d(pool_size_cnn)) # Max pooling
            in_channels = out_channels
        self.irf_cnn = nn.Sequential(*irf_cnn_layers)

        # Calculate flattened size after CNN layers by running a tryal forward pass
        example_input = torch.randn(1, 1, 4096) # Dummy input for size calculation
        hist_cnn_output_size = self._get_cnn_output_size(self.hist_cnn, example_input)
        irf_cnn_output_size = self._get_cnn_output_size(self.irf_cnn, example_input)
        combined_cnn_output_size = hist_cnn_output_size + irf_cnn_output_size

        # Fully connected layers with BatchNorm
        fc_layers = []
        fc_layer_sizes = config.get('fc_layer_sizes', [128, 64]) # Default FC layer sizes
        dropout_rate_fc = config.get('dropout_rate_fc', 0.2) # Configurable dropout
        in_features = combined_cnn_output_size

        for layer_size in fc_layer_sizes:
            fc_layers.append(nn.Linear(in_features, layer_size)) # Fully connected layer
            fc_layers.append(nn.BatchNorm1d(layer_size)) # Batch norm layer
            fc_layers.append(nn.ReLU()) # ReLU activation
            fc_layers.append(nn.Dropout(dropout_rate_fc)) # Dropout layer
            in_features = layer_size
        fc_layers.append(nn.Linear(in_features, 2)) # Output layer (ups and ua)
        fc_layers.append(ExpLayer()) # Ensure positive output using Exponential activation
        self.fc = nn.Sequential(*fc_layers)


    def _get_cnn_output_size(self, cnn_layers, input_tensor):
        '''
        Helper function to calculate the output size after custom CNN layers
        '''
        output = cnn_layers(input_tensor)
        return int(np.prod(output.size()[1:])) # Return flattened size

    def forward(self, histogram, irf):
        hist_features = self.hist_cnn(histogram)
        hist_features = hist_features.view(hist_features.size(0), -1) # Flatten
        irf_features = self.irf_cnn(irf)
        irf_features = irf_features.view(irf_features.size(0), -1) # Flatten
        combined_features = torch.cat((hist_features, irf_features), dim=1)
        output = self.fc(combined_features)
        return output

# Custom MSE Loss with UA Weight
class MSELossWeightedUA(nn.Module):
    def __init__(self, ua_weight=1.0): # Add ua_weight as a parameter, default to 1.0
        super().__init__()
        self.ua_weight = ua_weight

    def forward(self, predictions, targets):
        # No need to clamp predictions here as ExpLayer ensures positivity
        # Targets are assumed to be positive or non-negative

        squared_error = (predictions - targets)**2

        # Separate errors for ups and ua
        ups_error = squared_error[:, 0] # Error for ups (first output)
        ua_error = squared_error[:, 1]  # Error for ua (second output)

        # Apply weight to ua error
        weighted_ua_error = self.ua_weight * ua_error

        # Combine the losses (sum and then average)
        loss = torch.mean(ups_error + weighted_ua_error)

        return loss


def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs=100, device="cpu", clip_grad=1.0, patience=10): # Added patience for early stopping
    model.to(device)
    train_losses = []
    val_losses = []
    learning_rates = []

    best_val_loss = float('inf') # Initialize best validation loss to infinity
    epochs_no_improve = 0       # Counter for epochs with no improvement
    best_model_state = None      # Store the state of the best model

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for histograms, irfs, ups, ua in train_loader:
            histograms = histograms.to(device)
            irfs = irfs.to(device)
            ups = ups.to(device)
            ua = ua.to(device)

            optimizer.zero_grad()
            outputs = model(histograms, irfs)
            loss = criterion(outputs, torch.stack((ups, ua), dim=1))
            loss.backward()

            if clip_grad is not None:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_grad)

            optimizer.step()
            running_loss += loss.item()

        epoch_train_loss = running_loss / len(train_loader)
        train_losses.append(epoch_train_loss)

        model.eval()
        val_running_loss = 0.0
        with torch.no_grad():
            for histograms, irfs, ups, ua in val_loader:
                histograms = histograms.to(device)
                irfs = irfs.to(device)
                ups = ups.to(device)
                ua = ua.to(device)
                outputs = model(histograms, irfs)
                val_loss = criterion(outputs, torch.stack((ups, ua), dim=1))
                val_running_loss += val_loss.item()

        epoch_val_loss = val_running_loss / len(val_loader)
        val_losses.append(epoch_val_loss)

        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(current_lr)

        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f}, LR: {current_lr:.6f}')

        # Early stopping check
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            epochs_no_improve = 0 # Reset counter
            best_model_state = model.state_dict() # Save the state of the current best model
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            print(f'Early stopping triggered after epoch {epoch+1}. Validation loss did not improve for {patience} epochs.')
            model.load_state_dict(best_model_state) # Load the best model state
            break # Stop training

    return model, train_losses, val_losses, learning_rates

# %%
histograms_data = np.load('sim_results_1.npy')
irfs_data = np.load('sim_irfs_1.npy')
tags = np.load('sim_tags_1.npy')
ua_data = tags[:, 0]
ups_data = tags[:, 1]

print(len(ups_data))
print(ups_data)
print(ua_data)
# Out:
# 1500
# [0.77297297 0.77297297 1.75315315 ... 1.80900901 1.32972973 1.32972973]
# [0.01666667 0.01666667 0.01425225 ... 0.01641441 0.01205405 0.01205405]

# %%
## 2. Split data into training and validation sets
histograms_train, histograms_val, irfs_train, irfs_val, ups_train, ups_val, ua_train, ua_val = train_test_split(
    histograms_data, irfs_data, ups_data, ua_data, test_size=0.2, random_state=42
)

# 3. Create Datasets and DataLoaders
batch_size = 128

train_dataset = TurbidMediaDataset(histograms_train, irfs_train, ups_train, ua_train)
val_dataset = TurbidMediaDataset(histograms_val, irfs_val, ups_val, ua_val)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# 4. Define Network Configuration
network_config = {
        'cnn_filters_hist': [16, 32, 128, 256, 1024, 2048], # More CNN filters for histogram branch
        'cnn_filters_irf': [16, 32, 128, 256, 1024, 2048],  # More CNN filters for IRF branch
        'kernel_size_cnn': 20,             # Larger kernel size
        'pool_size_cnn': 2,
        'padding_cnn': 2,                 # Adjusted padding for larger kernel
        'use_batchnorm_cnn': True,        # <---- Ensure this is True to use BatchNorm in CNNs
        'fc_layer_sizes': [2048, 1024, 256, 128, 32, 16],  # More FC layers and larger sizes
        'dropout_rate_fc': 0.3            # Increased dropout rate
    }

# 5. Initialize Model, Loss function, Optimizer, and Scheduler
model = OpticalPropertiesEstimator(network_config)
criterion = MSELossWeightedUA(ua_weight=300.0)
optimizer = optim.Adam(model.parameters(), lr=0.002)

# Initialize StepLR scheduler - reduce LR by factor of 0.1 every 30 epochs
scheduler = StepLR(optimizer, step_size=200, gamma=0.8) # <---- Initialize StepLR

# 6. Train the Model (pass scheduler to train_model)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trained_model, train_losses, val_losses, learning_rates = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs=2000, device=device, clip_grad=1.0, patience=100) # Added scheduler

print("Training finished!")
# Out:
# Epoch 1/2000, Train Loss: 358.7823, Val Loss: 112529989348010.6719, LR: 0.002000
# Epoch 2/2000, Train Loss: 259.5597, Val Loss: 214.8335, LR: 0.002000
# Epoch 3/2000, Train Loss: 152.3903, Val Loss: 68.0832, LR: 0.002000
# Epoch 4/2000, Train Loss: 92.0870, Val Loss: 76.8958, LR: 0.002000
# Epoch 5/2000, Train Loss: 59.2506, Val Loss: 45.4855, LR: 0.002000
# Epoch 6/2000, Train Loss: 34.9012, Val Loss: 30.1649, LR: 0.002000
# Epoch 7/2000, Train Loss: 23.8394, Val Loss: 19.7949, LR: 0.002000
# Epoch 8/2000, Train Loss: 15.5471, Val Loss: 10.7200, LR: 0.002000
# Epoch 9/2000, Train Loss: 11.1909, Val Loss: 5.4996, LR: 0.002000
# Epoch 10/2000, Train Loss: 7.6170, Val Loss: 2.5327, LR: 0.002000
# Epoch 11/2000, Train Loss: 4.5965, Val Loss: 1.3559, LR: 0.002000
# Epoch 12/2000, Train Loss: 3.0489, Val Loss: 0.8488, LR: 0.002000
# Epoch 13/2000, Train Loss: 2.2296, Val Loss: 0.3399, LR: 0.002000
# Epoch 14/2000, Train Loss: 1.3429, Val Loss: 0.1873, LR: 0.002000
# Epoch 15/2000, Train Loss: 1.2188, Val Loss: 0.1297, LR: 0.002000
# Epoch 16/2000, Train Loss: 0.6348, Val Loss: 0.1043, LR: 0.002000
# Epoch 17/2000, Train Loss: 0.6115, Val Loss: 0.0891, LR: 0.002000
# Epoch 18/2000, Train Loss: 0.4333, Val Loss: 0.0814, LR: 0.002000
# Epoch 19/2000, Train Loss: 0.3894, Val Loss: 0.0850, LR: 0.002000
# Epoch 20/2000, Train Loss: 0.3336, Val Loss: 0.0988, LR: 0.002000
# Epoch 21/2000, Train Loss: 0.3506, Val Loss: 0.1123, LR: 0.002000
# Epoch 22/2000, Train Loss: 0.2773, Val Loss: 0.1073, LR: 0.002000
# Epoch 23/2000, Train Loss: 0.1750, Val Loss: 0.1023, LR: 0.002000
# Epoch 24/2000, Train Loss: 0.1632, Val Loss: 0.0916, LR: 0.002000
# Epoch 25/2000, Train Loss: 0.1471, Val Loss: 0.0906, LR: 0.002000
# Epoch 26/2000, Train Loss: 0.1397, Val Loss: 0.0753, LR: 0.002000
# Epoch 27/2000, Train Loss: 0.1206, Val Loss: 0.0731, LR: 0.002000
# Epoch 28/2000, Train Loss: 0.1423, Val Loss: 0.0730, LR: 0.002000
# Epoch 29/2000, Train Loss: 0.2065, Val Loss: 0.0780, LR: 0.002000
# Epoch 30/2000, Train Loss: 0.1423, Val Loss: 0.0753, LR: 0.002000
# Epoch 31/2000, Train Loss: 0.1955, Val Loss: 0.1168, LR: 0.002000
# Epoch 32/2000, Train Loss: 0.1428, Val Loss: 0.0741, LR: 0.002000
# Epoch 33/2000, Train Loss: 0.1451, Val Loss: 0.0681, LR: 0.002000
# Epoch 34/2000, Train Loss: 0.1097, Val Loss: 0.0677, LR: 0.002000
# Epoch 35/2000, Train Loss: 0.1228, Val Loss: 0.0724, LR: 0.002000
# Epoch 36/2000, Train Loss: 0.1176, Val Loss: 0.0695, LR: 0.002000
# Epoch 37/2000, Train Loss: 0.1280, Val Loss: 0.0736, LR: 0.002000
# Epoch 38/2000, Train Loss: 0.1047, Val Loss: 0.0740, LR: 0.002000
# Epoch 39/2000, Train Loss: 0.1119, Val Loss: 0.0776, LR: 0.002000
# Epoch 40/2000, Train Loss: 0.1148, Val Loss: 0.4466, LR: 0.002000
# Epoch 41/2000, Train Loss: 0.1254, Val Loss: 0.1926, LR: 0.002000
# Epoch 42/2000, Train Loss: 0.0968, Val Loss: 0.0688, LR: 0.002000
# Epoch 43/2000, Train Loss: 0.1210, Val Loss: 0.0664, LR: 0.002000
# Epoch 44/2000, Train Loss: 0.1297, Val Loss: 0.0803, LR: 0.002000
# Epoch 45/2000, Train Loss: 0.1332, Val Loss: 0.0885, LR: 0.002000
# Epoch 46/2000, Train Loss: 0.1409, Val Loss: 0.0512, LR: 0.002000
# Epoch 47/2000, Train Loss: 0.0921, Val Loss: 0.0575, LR: 0.002000
# Epoch 48/2000, Train Loss: 0.1032, Val Loss: 0.0607, LR: 0.002000
# Epoch 49/2000, Train Loss: 0.0930, Val Loss: 0.0586, LR: 0.002000
# Epoch 50/2000, Train Loss: 0.1103, Val Loss: 0.1787, LR: 0.002000
# Epoch 51/2000, Train Loss: 0.1002, Val Loss: 0.1524, LR: 0.002000
# Epoch 52/2000, Train Loss: 0.0918, Val Loss: 0.0719, LR: 0.002000
# Epoch 53/2000, Train Loss: 0.0867, Val Loss: 0.0552, LR: 0.002000
# Epoch 54/2000, Train Loss: 0.0790, Val Loss: 0.0491, LR: 0.002000
# Epoch 55/2000, Train Loss: 0.0992, Val Loss: 0.0457, LR: 0.002000
# Epoch 56/2000, Train Loss: 0.0873, Val Loss: 0.0438, LR: 0.002000
# Epoch 57/2000, Train Loss: 0.0913, Val Loss: 0.0827, LR: 0.002000
# Epoch 58/2000, Train Loss: 0.0831, Val Loss: 0.0514, LR: 0.002000
# Epoch 59/2000, Train Loss: 0.0936, Val Loss: 0.0601, LR: 0.002000
# Epoch 60/2000, Train Loss: 0.0760, Val Loss: 0.0506, LR: 0.002000
# Epoch 61/2000, Train Loss: 0.0973, Val Loss: 0.0754, LR: 0.002000
# Epoch 62/2000, Train Loss: 0.1008, Val Loss: 0.0713, LR: 0.002000
# Epoch 63/2000, Train Loss: 0.1065, Val Loss: 0.0717, LR: 0.002000
# Epoch 64/2000, Train Loss: 0.0975, Val Loss: 0.0781, LR: 0.002000
# Epoch 65/2000, Train Loss: 0.0911, Val Loss: 0.0637, LR: 0.002000
# Epoch 66/2000, Train Loss: 0.0826, Val Loss: 0.0570, LR: 0.002000
# Epoch 67/2000, Train Loss: 0.0840, Val Loss: 0.0637, LR: 0.002000
# Epoch 68/2000, Train Loss: 0.0828, Val Loss: 0.0684, LR: 0.002000
# Epoch 69/2000, Train Loss: 0.0881, Val Loss: 0.0493, LR: 0.002000
# Epoch 70/2000, Train Loss: 0.0801, Val Loss: 0.0472, LR: 0.002000
# Epoch 71/2000, Train Loss: 0.0844, Val Loss: 0.0500, LR: 0.002000
# Epoch 72/2000, Train Loss: 0.0785, Val Loss: 0.0509, LR: 0.002000
# Epoch 73/2000, Train Loss: 0.0811, Val Loss: 0.0449, LR: 0.002000
# Epoch 74/2000, Train Loss: 0.0746, Val Loss: 0.0458, LR: 0.002000
# Epoch 75/2000, Train Loss: 0.0962, Val Loss: 0.0891, LR: 0.002000
# Epoch 76/2000, Train Loss: 0.0887, Val Loss: 0.1097, LR: 0.002000
# Epoch 77/2000, Train Loss: 0.0967, Val Loss: 0.0917, LR: 0.002000
# Epoch 78/2000, Train Loss: 0.0829, Val Loss: 0.1061, LR: 0.002000
# Epoch 79/2000, Train Loss: 0.0798, Val Loss: 0.0799, LR: 0.002000
# Epoch 80/2000, Train Loss: 0.0997, Val Loss: 0.0602, LR: 0.002000
# Epoch 81/2000, Train Loss: 0.0838, Val Loss: 0.0661, LR: 0.002000
# Epoch 82/2000, Train Loss: 0.0870, Val Loss: 0.0529, LR: 0.002000
# Epoch 83/2000, Train Loss: 0.0925, Val Loss: 0.0509, LR: 0.002000
# Epoch 84/2000, Train Loss: 0.0718, Val Loss: 0.0608, LR: 0.002000
# Epoch 85/2000, Train Loss: 0.0875, Val Loss: 0.0546, LR: 0.002000
# Epoch 86/2000, Train Loss: 0.0814, Val Loss: 0.0732, LR: 0.002000
# Epoch 87/2000, Train Loss: 0.0825, Val Loss: 0.0593, LR: 0.002000
# Epoch 88/2000, Train Loss: 0.0722, Val Loss: 0.0486, LR: 0.002000
# Epoch 89/2000, Train Loss: 0.0710, Val Loss: 0.0713, LR: 0.002000
# Epoch 90/2000, Train Loss: 0.0690, Val Loss: 0.0454, LR: 0.002000
# Epoch 91/2000, Train Loss: 0.0841, Val Loss: 0.2021, LR: 0.002000
# Epoch 92/2000, Train Loss: 0.0697, Val Loss: 0.1730, LR: 0.002000
# Epoch 93/2000, Train Loss: 0.0746, Val Loss: 0.0689, LR: 0.002000
# Epoch 94/2000, Train Loss: 0.0658, Val Loss: 0.0448, LR: 0.002000
# Epoch 95/2000, Train Loss: 0.0716, Val Loss: 0.0426, LR: 0.002000
# Epoch 96/2000, Train Loss: 0.0716, Val Loss: 0.0440, LR: 0.002000
# Epoch 97/2000, Train Loss: 0.0965, Val Loss: 0.0752, LR: 0.002000
# Epoch 98/2000, Train Loss: 0.0794, Val Loss: 0.0500, LR: 0.002000
# Epoch 99/2000, Train Loss: 0.0766, Val Loss: 0.0504, LR: 0.002000
# Epoch 100/2000, Train Loss: 0.0921, Val Loss: 0.0501, LR: 0.002000
# Epoch 101/2000, Train Loss: 0.0739, Val Loss: 0.0505, LR: 0.002000
# Epoch 102/2000, Train Loss: 0.0701, Val Loss: 0.0487, LR: 0.002000
# Epoch 103/2000, Train Loss: 0.1311, Val Loss: 0.0467, LR: 0.002000
# Epoch 104/2000, Train Loss: 0.0868, Val Loss: 0.0566, LR: 0.002000
# Epoch 105/2000, Train Loss: 0.0834, Val Loss: 0.0991, LR: 0.002000
# Epoch 106/2000, Train Loss: 0.0708, Val Loss: 0.0928, LR: 0.002000
# Epoch 107/2000, Train Loss: 0.0752, Val Loss: 0.0682, LR: 0.002000
# Epoch 108/2000, Train Loss: 0.0703, Val Loss: 0.0470, LR: 0.002000
# Epoch 109/2000, Train Loss: 0.0723, Val Loss: 0.0455, LR: 0.002000
# Epoch 110/2000, Train Loss: 0.0700, Val Loss: 0.0683, LR: 0.002000
# Epoch 111/2000, Train Loss: 0.0667, Val Loss: 0.0630, LR: 0.002000
# Epoch 112/2000, Train Loss: 0.0687, Val Loss: 0.0466, LR: 0.002000
# Epoch 113/2000, Train Loss: 0.0688, Val Loss: 0.0681, LR: 0.002000
# Epoch 114/2000, Train Loss: 0.0687, Val Loss: 0.0545, LR: 0.002000
# Epoch 115/2000, Train Loss: 0.0702, Val Loss: 0.1091, LR: 0.002000
# Epoch 116/2000, Train Loss: 0.0691, Val Loss: 0.0806, LR: 0.002000
# Epoch 117/2000, Train Loss: 0.0738, Val Loss: 0.0589, LR: 0.002000
# Epoch 118/2000, Train Loss: 0.0637, Val Loss: 0.0543, LR: 0.002000
# Epoch 119/2000, Train Loss: 0.0636, Val Loss: 0.0491, LR: 0.002000
# Epoch 120/2000, Train Loss: 0.0622, Val Loss: 0.0450, LR: 0.002000
# Epoch 121/2000, Train Loss: 0.0810, Val Loss: 0.0446, LR: 0.002000
# Epoch 122/2000, Train Loss: 0.0767, Val Loss: 0.0471, LR: 0.002000
# Epoch 123/2000, Train Loss: 0.0610, Val Loss: 0.0652, LR: 0.002000
# Epoch 124/2000, Train Loss: 0.0719, Val Loss: 0.0426, LR: 0.002000
# Epoch 125/2000, Train Loss: 0.0640, Val Loss: 0.0420, LR: 0.002000
# Epoch 126/2000, Train Loss: 0.0620, Val Loss: 0.0426, LR: 0.002000
# Epoch 127/2000, Train Loss: 0.0819, Val Loss: 0.1404, LR: 0.002000
# Epoch 128/2000, Train Loss: 0.0690, Val Loss: 0.0666, LR: 0.002000
# Epoch 129/2000, Train Loss: 0.0678, Val Loss: 0.0578, LR: 0.002000
# Epoch 130/2000, Train Loss: 0.0645, Val Loss: 0.0452, LR: 0.002000
# Epoch 131/2000, Train Loss: 0.0625, Val Loss: 0.0406, LR: 0.002000
# Epoch 132/2000, Train Loss: 0.0843, Val Loss: 0.0424, LR: 0.002000
# Epoch 133/2000, Train Loss: 0.0650, Val Loss: 0.0472, LR: 0.002000
# Epoch 134/2000, Train Loss: 0.0685, Val Loss: 0.0472, LR: 0.002000
# Epoch 135/2000, Train Loss: 0.0691, Val Loss: 0.0422, LR: 0.002000
# Epoch 136/2000, Train Loss: 0.0668, Val Loss: 0.0399, LR: 0.002000
# Epoch 137/2000, Train Loss: 0.0681, Val Loss: 0.0443, LR: 0.002000
# Epoch 138/2000, Train Loss: 0.0896, Val Loss: 0.0460, LR: 0.002000
# Epoch 139/2000, Train Loss: 0.0655, Val Loss: 0.0717, LR: 0.002000
# Epoch 140/2000, Train Loss: 0.0825, Val Loss: 0.0728, LR: 0.002000
# Epoch 141/2000, Train Loss: 0.0638, Val Loss: 0.0529, LR: 0.002000
# Epoch 142/2000, Train Loss: 0.0620, Val Loss: 0.0434, LR: 0.002000
# Epoch 143/2000, Train Loss: 0.0648, Val Loss: 0.0619, LR: 0.002000
# Epoch 144/2000, Train Loss: 0.0621, Val Loss: 0.0723, LR: 0.002000
# Epoch 145/2000, Train Loss: 0.0667, Val Loss: 0.0627, LR: 0.002000
# Epoch 146/2000, Train Loss: 0.0601, Val Loss: 0.1257, LR: 0.002000
# Epoch 147/2000, Train Loss: 0.0622, Val Loss: 0.0953, LR: 0.002000
# Epoch 148/2000, Train Loss: 0.0597, Val Loss: 0.0448, LR: 0.002000
# Epoch 149/2000, Train Loss: 0.0593, Val Loss: 0.0476, LR: 0.002000
# Epoch 150/2000, Train Loss: 0.0741, Val Loss: 0.0415, LR: 0.002000
# Epoch 151/2000, Train Loss: 0.0756, Val Loss: 0.0436, LR: 0.002000
# Epoch 152/2000, Train Loss: 0.0659, Val Loss: 0.0505, LR: 0.002000
# Epoch 153/2000, Train Loss: 0.0695, Val Loss: 0.0485, LR: 0.002000
# Epoch 154/2000, Train Loss: 0.0665, Val Loss: 0.0471, LR: 0.002000
# Epoch 155/2000, Train Loss: 0.0640, Val Loss: 0.0532, LR: 0.002000
# Epoch 156/2000, Train Loss: 0.0615, Val Loss: 0.0402, LR: 0.002000
# Epoch 157/2000, Train Loss: 0.0705, Val Loss: 0.0401, LR: 0.002000
# Epoch 158/2000, Train Loss: 0.0651, Val Loss: 0.0404, LR: 0.002000
# Epoch 159/2000, Train Loss: 0.0664, Val Loss: 0.0492, LR: 0.002000
# Epoch 160/2000, Train Loss: 0.0660, Val Loss: 0.0477, LR: 0.002000
# Epoch 161/2000, Train Loss: 0.0680, Val Loss: 0.0467, LR: 0.002000
# Epoch 162/2000, Train Loss: 0.0608, Val Loss: 0.0660, LR: 0.002000
# Epoch 163/2000, Train Loss: 0.0646, Val Loss: 0.0707, LR: 0.002000
# Epoch 164/2000, Train Loss: 0.0620, Val Loss: 0.0457, LR: 0.002000
# Epoch 165/2000, Train Loss: 0.0634, Val Loss: 0.0423, LR: 0.002000
# Epoch 166/2000, Train Loss: 0.0589, Val Loss: 0.0375, LR: 0.002000
# Epoch 167/2000, Train Loss: 0.0668, Val Loss: 0.0357, LR: 0.002000
# Epoch 168/2000, Train Loss: 0.0569, Val Loss: 0.0433, LR: 0.002000
# Epoch 169/2000, Train Loss: 0.0675, Val Loss: 0.0376, LR: 0.002000
# Epoch 170/2000, Train Loss: 0.0618, Val Loss: 0.0368, LR: 0.002000
# Epoch 171/2000, Train Loss: 0.0558, Val Loss: 0.0378, LR: 0.002000
# Epoch 172/2000, Train Loss: 0.0603, Val Loss: 0.0368, LR: 0.002000
# Epoch 173/2000, Train Loss: 0.0588, Val Loss: 0.0377, LR: 0.002000
# Epoch 174/2000, Train Loss: 0.0611, Val Loss: 0.0414, LR: 0.002000
# Epoch 175/2000, Train Loss: 0.0589, Val Loss: 0.0359, LR: 0.002000
# Epoch 176/2000, Train Loss: 0.0611, Val Loss: 0.0358, LR: 0.002000
# Epoch 177/2000, Train Loss: 0.0548, Val Loss: 0.0375, LR: 0.002000
# Epoch 178/2000, Train Loss: 0.0575, Val Loss: 0.0365, LR: 0.002000
# Epoch 179/2000, Train Loss: 0.0560, Val Loss: 0.0352, LR: 0.002000
# Epoch 180/2000, Train Loss: 0.0522, Val Loss: 0.0385, LR: 0.002000
# Epoch 181/2000, Train Loss: 0.0611, Val Loss: 0.0360, LR: 0.002000
# Epoch 182/2000, Train Loss: 0.0992, Val Loss: 0.0339, LR: 0.002000
# Epoch 183/2000, Train Loss: 0.0579, Val Loss: 0.0462, LR: 0.002000
# Epoch 184/2000, Train Loss: 0.0725, Val Loss: 0.0637, LR: 0.002000
# Epoch 185/2000, Train Loss: 0.0688, Val Loss: 0.1022, LR: 0.002000
# Epoch 186/2000, Train Loss: 0.0630, Val Loss: 0.0604, LR: 0.002000
# Epoch 187/2000, Train Loss: 0.0620, Val Loss: 0.0408, LR: 0.002000
# Epoch 188/2000, Train Loss: 0.0741, Val Loss: 0.0694, LR: 0.002000
# Epoch 189/2000, Train Loss: 0.0666, Val Loss: 0.0389, LR: 0.002000
# Epoch 190/2000, Train Loss: 0.0629, Val Loss: 0.0405, LR: 0.002000
# Epoch 191/2000, Train Loss: 0.0580, Val Loss: 0.0836, LR: 0.002000
# Epoch 192/2000, Train Loss: 0.0591, Val Loss: 0.0665, LR: 0.002000
# Epoch 193/2000, Train Loss: 0.0583, Val Loss: 0.0435, LR: 0.002000
# Epoch 194/2000, Train Loss: 0.0602, Val Loss: 0.0522, LR: 0.002000
# Epoch 195/2000, Train Loss: 0.0948, Val Loss: 0.0561, LR: 0.002000
# Epoch 196/2000, Train Loss: 0.0647, Val Loss: 0.1161, LR: 0.002000
# Epoch 197/2000, Train Loss: 0.0586, Val Loss: 0.0739, LR: 0.002000
# Epoch 198/2000, Train Loss: 0.0598, Val Loss: 0.0770, LR: 0.002000
# Epoch 199/2000, Train Loss: 0.0604, Val Loss: 0.0528, LR: 0.002000
# Epoch 200/2000, Train Loss: 0.0581, Val Loss: 0.0590, LR: 0.001600
# Epoch 201/2000, Train Loss: 0.0607, Val Loss: 0.0393, LR: 0.001600
# Epoch 202/2000, Train Loss: 0.0606, Val Loss: 0.0414, LR: 0.001600
# Epoch 203/2000, Train Loss: 0.0932, Val Loss: 0.0378, LR: 0.001600
# Epoch 204/2000, Train Loss: 0.0572, Val Loss: 0.0417, LR: 0.001600
# Epoch 205/2000, Train Loss: 0.0561, Val Loss: 0.0406, LR: 0.001600
# Epoch 206/2000, Train Loss: 0.0621, Val Loss: 0.0435, LR: 0.001600
# Epoch 207/2000, Train Loss: 0.0592, Val Loss: 0.0921, LR: 0.001600
# Epoch 208/2000, Train Loss: 0.0593, Val Loss: 0.0862, LR: 0.001600
# Epoch 209/2000, Train Loss: 0.0527, Val Loss: 0.0470, LR: 0.001600
# Epoch 210/2000, Train Loss: 0.0604, Val Loss: 0.0353, LR: 0.001600
# Epoch 211/2000, Train Loss: 0.0566, Val Loss: 0.0346, LR: 0.001600
# Epoch 212/2000, Train Loss: 0.0680, Val Loss: 0.0669, LR: 0.001600
# Epoch 213/2000, Train Loss: 0.0599, Val Loss: 0.0433, LR: 0.001600
# Epoch 214/2000, Train Loss: 0.0627, Val Loss: 0.0368, LR: 0.001600
# Epoch 215/2000, Train Loss: 0.0575, Val Loss: 0.0358, LR: 0.001600
# Epoch 216/2000, Train Loss: 0.0589, Val Loss: 0.0338, LR: 0.001600
# Epoch 217/2000, Train Loss: 0.0571, Val Loss: 0.0470, LR: 0.001600
# Epoch 218/2000, Train Loss: 0.0542, Val Loss: 0.0358, LR: 0.001600
# Epoch 219/2000, Train Loss: 0.0548, Val Loss: 0.0333, LR: 0.001600
# Epoch 220/2000, Train Loss: 0.0530, Val Loss: 0.0342, LR: 0.001600
# Epoch 221/2000, Train Loss: 0.0527, Val Loss: 0.0431, LR: 0.001600
# Epoch 222/2000, Train Loss: 0.0562, Val Loss: 0.0438, LR: 0.001600
# Epoch 223/2000, Train Loss: 0.0582, Val Loss: 0.0380, LR: 0.001600
# Epoch 224/2000, Train Loss: 0.0567, Val Loss: 0.0374, LR: 0.001600
# Epoch 225/2000, Train Loss: 0.0588, Val Loss: 0.0536, LR: 0.001600
# Epoch 226/2000, Train Loss: 0.0560, Val Loss: 0.0599, LR: 0.001600
# Epoch 227/2000, Train Loss: 0.0607, Val Loss: 0.0481, LR: 0.001600
# Epoch 228/2000, Train Loss: 0.0581, Val Loss: 0.0410, LR: 0.001600
# Epoch 229/2000, Train Loss: 0.0554, Val Loss: 0.0338, LR: 0.001600
# Epoch 230/2000, Train Loss: 0.0602, Val Loss: 0.0621, LR: 0.001600
# Epoch 231/2000, Train Loss: 0.0555, Val Loss: 0.0400, LR: 0.001600
# Epoch 232/2000, Train Loss: 0.0590, Val Loss: 0.0972, LR: 0.001600
# Epoch 233/2000, Train Loss: 0.0572, Val Loss: 0.0750, LR: 0.001600
# Epoch 234/2000, Train Loss: 0.0558, Val Loss: 0.0397, LR: 0.001600
# Epoch 235/2000, Train Loss: 0.0534, Val Loss: 0.0355, LR: 0.001600
# Epoch 236/2000, Train Loss: 0.0560, Val Loss: 0.0420, LR: 0.001600
# Epoch 237/2000, Train Loss: 0.0528, Val Loss: 0.0454, LR: 0.001600
# Epoch 238/2000, Train Loss: 0.0620, Val Loss: 0.0785, LR: 0.001600
# Epoch 239/2000, Train Loss: 0.0514, Val Loss: 0.0658, LR: 0.001600
# Epoch 240/2000, Train Loss: 0.0612, Val Loss: 0.0381, LR: 0.001600
# Epoch 241/2000, Train Loss: 0.0598, Val Loss: 0.0410, LR: 0.001600
# Epoch 242/2000, Train Loss: 0.0571, Val Loss: 0.0562, LR: 0.001600
# Epoch 243/2000, Train Loss: 0.0553, Val Loss: 0.0643, LR: 0.001600
# Epoch 244/2000, Train Loss: 0.0564, Val Loss: 0.0483, LR: 0.001600
# Epoch 245/2000, Train Loss: 0.0525, Val Loss: 0.0418, LR: 0.001600
# Epoch 246/2000, Train Loss: 0.0546, Val Loss: 0.0492, LR: 0.001600
# Epoch 247/2000, Train Loss: 0.0553, Val Loss: 0.0339, LR: 0.001600
# Epoch 248/2000, Train Loss: 0.0626, Val Loss: 0.0312, LR: 0.001600
# Epoch 249/2000, Train Loss: 0.0523, Val Loss: 0.0321, LR: 0.001600
# Epoch 250/2000, Train Loss: 0.0555, Val Loss: 0.0328, LR: 0.001600
# Epoch 251/2000, Train Loss: 0.0513, Val Loss: 0.0386, LR: 0.001600
# Epoch 252/2000, Train Loss: 0.0543, Val Loss: 0.0348, LR: 0.001600
# Epoch 253/2000, Train Loss: 0.0572, Val Loss: 0.0445, LR: 0.001600
# Epoch 254/2000, Train Loss: 0.0575, Val Loss: 0.0337, LR: 0.001600
# Epoch 255/2000, Train Loss: 0.0562, Val Loss: 0.0349, LR: 0.001600
# Epoch 256/2000, Train Loss: 0.0667, Val Loss: 0.0359, LR: 0.001600
# Epoch 257/2000, Train Loss: 0.0542, Val Loss: 0.0381, LR: 0.001600
# Epoch 258/2000, Train Loss: 0.0567, Val Loss: 0.0420, LR: 0.001600
# Epoch 259/2000, Train Loss: 0.0555, Val Loss: 0.0392, LR: 0.001600
# Epoch 260/2000, Train Loss: 0.0561, Val Loss: 0.0485, LR: 0.001600
# Epoch 261/2000, Train Loss: 0.0576, Val Loss: 0.0322, LR: 0.001600
# Epoch 262/2000, Train Loss: 0.0508, Val Loss: 0.0398, LR: 0.001600
# Epoch 263/2000, Train Loss: 0.0555, Val Loss: 0.0321, LR: 0.001600
# Epoch 264/2000, Train Loss: 0.0580, Val Loss: 0.0346, LR: 0.001600
# Epoch 265/2000, Train Loss: 0.0553, Val Loss: 0.0338, LR: 0.001600
# Epoch 266/2000, Train Loss: 0.0595, Val Loss: 0.0370, LR: 0.001600
# Epoch 267/2000, Train Loss: 0.0576, Val Loss: 0.0424, LR: 0.001600
# Epoch 268/2000, Train Loss: 0.0539, Val Loss: 0.0611, LR: 0.001600
# Epoch 269/2000, Train Loss: 0.0543, Val Loss: 0.0362, LR: 0.001600
# Epoch 270/2000, Train Loss: 0.0514, Val Loss: 0.0315, LR: 0.001600
# Epoch 271/2000, Train Loss: 0.0512, Val Loss: 0.0327, LR: 0.001600
# Epoch 272/2000, Train Loss: 0.0573, Val Loss: 0.0640, LR: 0.001600
# Epoch 273/2000, Train Loss: 0.0555, Val Loss: 0.0726, LR: 0.001600
# Epoch 274/2000, Train Loss: 0.0499, Val Loss: 0.1117, LR: 0.001600
# Epoch 275/2000, Train Loss: 0.0557, Val Loss: 0.0908, LR: 0.001600
# Epoch 276/2000, Train Loss: 0.0534, Val Loss: 0.0538, LR: 0.001600
# Epoch 277/2000, Train Loss: 0.0495, Val Loss: 0.0933, LR: 0.001600
# Epoch 278/2000, Train Loss: 0.0525, Val Loss: 0.0594, LR: 0.001600
# Epoch 279/2000, Train Loss: 0.0521, Val Loss: 0.0367, LR: 0.001600
# Epoch 280/2000, Train Loss: 0.0494, Val Loss: 0.0458, LR: 0.001600
# Epoch 281/2000, Train Loss: 0.0604, Val Loss: 0.1469, LR: 0.001600
# Epoch 282/2000, Train Loss: 0.0590, Val Loss: 0.1874, LR: 0.001600
# Epoch 283/2000, Train Loss: 0.0566, Val Loss: 0.1077, LR: 0.001600
# Epoch 284/2000, Train Loss: 0.0613, Val Loss: 0.0390, LR: 0.001600
# Epoch 285/2000, Train Loss: 0.0539, Val Loss: 0.0360, LR: 0.001600
# Epoch 286/2000, Train Loss: 0.0658, Val Loss: 0.0348, LR: 0.001600
# Epoch 287/2000, Train Loss: 0.0658, Val Loss: 0.0444, LR: 0.001600
# Epoch 288/2000, Train Loss: 0.0529, Val Loss: 0.0440, LR: 0.001600
# Epoch 289/2000, Train Loss: 0.0535, Val Loss: 0.0566, LR: 0.001600
# Epoch 290/2000, Train Loss: 0.0526, Val Loss: 0.0715, LR: 0.001600
# Epoch 291/2000, Train Loss: 0.0689, Val Loss: 0.0673, LR: 0.001600
# Epoch 292/2000, Train Loss: 0.0618, Val Loss: 0.0396, LR: 0.001600
# Epoch 293/2000, Train Loss: 0.0582, Val Loss: 0.0340, LR: 0.001600
# Epoch 294/2000, Train Loss: 0.0535, Val Loss: 0.0364, LR: 0.001600
# Epoch 295/2000, Train Loss: 0.0548, Val Loss: 0.0322, LR: 0.001600
# Epoch 296/2000, Train Loss: 0.0531, Val Loss: 0.0373, LR: 0.001600
# Epoch 297/2000, Train Loss: 0.0560, Val Loss: 0.0774, LR: 0.001600
# Epoch 298/2000, Train Loss: 0.0608, Val Loss: 0.0380, LR: 0.001600
# Epoch 299/2000, Train Loss: 0.0564, Val Loss: 0.0359, LR: 0.001600
# Epoch 300/2000, Train Loss: 0.0627, Val Loss: 0.0441, LR: 0.001600
# Epoch 301/2000, Train Loss: 0.0628, Val Loss: 0.1065, LR: 0.001600
# Epoch 302/2000, Train Loss: 0.0537, Val Loss: 0.0544, LR: 0.001600
# Epoch 303/2000, Train Loss: 0.0508, Val Loss: 0.0338, LR: 0.001600
# Epoch 304/2000, Train Loss: 0.0572, Val Loss: 0.0334, LR: 0.001600
# Epoch 305/2000, Train Loss: 0.0550, Val Loss: 0.0372, LR: 0.001600
# Epoch 306/2000, Train Loss: 0.0545, Val Loss: 0.0477, LR: 0.001600
# Epoch 307/2000, Train Loss: 0.0472, Val Loss: 0.0347, LR: 0.001600
# Epoch 308/2000, Train Loss: 0.0520, Val Loss: 0.0433, LR: 0.001600
# Epoch 309/2000, Train Loss: 0.0571, Val Loss: 0.0377, LR: 0.001600
# Epoch 310/2000, Train Loss: 0.0511, Val Loss: 0.0483, LR: 0.001600
# Epoch 311/2000, Train Loss: 0.0638, Val Loss: 0.1559, LR: 0.001600
# Epoch 312/2000, Train Loss: 0.0571, Val Loss: 0.0476, LR: 0.001600
# Epoch 313/2000, Train Loss: 0.0517, Val Loss: 0.0337, LR: 0.001600
# Epoch 314/2000, Train Loss: 0.0523, Val Loss: 0.0343, LR: 0.001600
# Epoch 315/2000, Train Loss: 0.0623, Val Loss: 0.0456, LR: 0.001600
# Epoch 316/2000, Train Loss: 0.0553, Val Loss: 0.0474, LR: 0.001600
# Epoch 317/2000, Train Loss: 0.0562, Val Loss: 0.0940, LR: 0.001600
# Epoch 318/2000, Train Loss: 0.0523, Val Loss: 0.1624, LR: 0.001600
# Epoch 319/2000, Train Loss: 0.0537, Val Loss: 0.1664, LR: 0.001600
# Epoch 320/2000, Train Loss: 0.0550, Val Loss: 0.1233, LR: 0.001600
# Epoch 321/2000, Train Loss: 0.0499, Val Loss: 0.0579, LR: 0.001600
# Epoch 322/2000, Train Loss: 0.0585, Val Loss: 0.0499, LR: 0.001600
# Epoch 323/2000, Train Loss: 0.0498, Val Loss: 0.0514, LR: 0.001600
# Epoch 324/2000, Train Loss: 0.0530, Val Loss: 0.0409, LR: 0.001600
# Epoch 325/2000, Train Loss: 0.0506, Val Loss: 0.0449, LR: 0.001600
# Epoch 326/2000, Train Loss: 0.0529, Val Loss: 0.0503, LR: 0.001600
# Epoch 327/2000, Train Loss: 0.0496, Val Loss: 0.0576, LR: 0.001600
# Epoch 328/2000, Train Loss: 0.0607, Val Loss: 0.0309, LR: 0.001600
# Epoch 329/2000, Train Loss: 0.0523, Val Loss: 0.0311, LR: 0.001600
# Epoch 330/2000, Train Loss: 0.0491, Val Loss: 0.0385, LR: 0.001600
# Epoch 331/2000, Train Loss: 0.0567, Val Loss: 0.0328, LR: 0.001600
# Epoch 332/2000, Train Loss: 0.0534, Val Loss: 0.0452, LR: 0.001600
# Epoch 333/2000, Train Loss: 0.0520, Val Loss: 0.0945, LR: 0.001600
# Epoch 334/2000, Train Loss: 0.0542, Val Loss: 0.0962, LR: 0.001600
# Epoch 335/2000, Train Loss: 0.0526, Val Loss: 0.0645, LR: 0.001600
# Epoch 336/2000, Train Loss: 0.0591, Val Loss: 0.0489, LR: 0.001600
# Epoch 337/2000, Train Loss: 0.0510, Val Loss: 0.0741, LR: 0.001600
# Epoch 338/2000, Train Loss: 0.0487, Val Loss: 0.2200, LR: 0.001600
# Epoch 339/2000, Train Loss: 0.0531, Val Loss: 0.1539, LR: 0.001600
# Epoch 340/2000, Train Loss: 0.0542, Val Loss: 0.0522, LR: 0.001600
# Epoch 341/2000, Train Loss: 0.0533, Val Loss: 0.0571, LR: 0.001600
# Epoch 342/2000, Train Loss: 0.0488, Val Loss: 0.0671, LR: 0.001600
# Epoch 343/2000, Train Loss: 0.0505, Val Loss: 0.0719, LR: 0.001600
# Epoch 344/2000, Train Loss: 0.0486, Val Loss: 0.0371, LR: 0.001600
# Epoch 345/2000, Train Loss: 0.0519, Val Loss: 0.0391, LR: 0.001600
# Epoch 346/2000, Train Loss: 0.0504, Val Loss: 0.0350, LR: 0.001600
# Epoch 347/2000, Train Loss: 0.0549, Val Loss: 0.0542, LR: 0.001600
# Epoch 348/2000, Train Loss: 0.0522, Val Loss: 0.0455, LR: 0.001600
# Epoch 349/2000, Train Loss: 0.0533, Val Loss: 0.0832, LR: 0.001600
# Epoch 350/2000, Train Loss: 0.0502, Val Loss: 0.0590, LR: 0.001600
# Epoch 351/2000, Train Loss: 0.0494, Val Loss: 0.0469, LR: 0.001600
# Epoch 352/2000, Train Loss: 0.0502, Val Loss: 0.0316, LR: 0.001600
# Epoch 353/2000, Train Loss: 0.0484, Val Loss: 0.0321, LR: 0.001600
# Epoch 354/2000, Train Loss: 0.0513, Val Loss: 0.0398, LR: 0.001600
# Epoch 355/2000, Train Loss: 0.0520, Val Loss: 0.0515, LR: 0.001600
# Epoch 356/2000, Train Loss: 0.0511, Val Loss: 0.0480, LR: 0.001600
# Epoch 357/2000, Train Loss: 0.0536, Val Loss: 0.0293, LR: 0.001600
# Epoch 358/2000, Train Loss: 0.0472, Val Loss: 0.0307, LR: 0.001600
# Epoch 359/2000, Train Loss: 0.0556, Val Loss: 0.0874, LR: 0.001600
# Epoch 360/2000, Train Loss: 0.0481, Val Loss: 0.0859, LR: 0.001600
# Epoch 361/2000, Train Loss: 0.0502, Val Loss: 0.0616, LR: 0.001600
# Epoch 362/2000, Train Loss: 0.0503, Val Loss: 0.0562, LR: 0.001600
# Epoch 363/2000, Train Loss: 0.0470, Val Loss: 0.0709, LR: 0.001600
# Epoch 364/2000, Train Loss: 0.0526, Val Loss: 0.0600, LR: 0.001600
# Epoch 365/2000, Train Loss: 0.0484, Val Loss: 0.1112, LR: 0.001600
# Epoch 366/2000, Train Loss: 0.0489, Val Loss: 0.1122, LR: 0.001600
# Epoch 367/2000, Train Loss: 0.0481, Val Loss: 0.0797, LR: 0.001600
# Epoch 368/2000, Train Loss: 0.0469, Val Loss: 0.0607, LR: 0.001600
# Epoch 369/2000, Train Loss: 0.0525, Val Loss: 0.0642, LR: 0.001600
# Epoch 370/2000, Train Loss: 0.0496, Val Loss: 0.1086, LR: 0.001600
# Epoch 371/2000, Train Loss: 0.0482, Val Loss: 0.0896, LR: 0.001600
# Epoch 372/2000, Train Loss: 0.0517, Val Loss: 0.1130, LR: 0.001600
# Epoch 373/2000, Train Loss: 0.0495, Val Loss: 0.0735, LR: 0.001600
# Epoch 374/2000, Train Loss: 0.0491, Val Loss: 0.0553, LR: 0.001600
# Epoch 375/2000, Train Loss: 0.0529, Val Loss: 0.0307, LR: 0.001600
# Epoch 376/2000, Train Loss: 0.0507, Val Loss: 0.0429, LR: 0.001600
# Epoch 377/2000, Train Loss: 0.0483, Val Loss: 0.0506, LR: 0.001600
# Epoch 378/2000, Train Loss: 0.0514, Val Loss: 0.0465, LR: 0.001600
# Epoch 379/2000, Train Loss: 0.0473, Val Loss: 0.0449, LR: 0.001600
# Epoch 380/2000, Train Loss: 0.0467, Val Loss: 0.0481, LR: 0.001600
# Epoch 381/2000, Train Loss: 0.0495, Val Loss: 0.0683, LR: 0.001600
# Epoch 382/2000, Train Loss: 0.0478, Val Loss: 0.0919, LR: 0.001600
# Epoch 383/2000, Train Loss: 0.0604, Val Loss: 0.1083, LR: 0.001600
# Epoch 384/2000, Train Loss: 0.0504, Val Loss: 0.0980, LR: 0.001600
# Epoch 385/2000, Train Loss: 0.0512, Val Loss: 0.0944, LR: 0.001600
# Epoch 386/2000, Train Loss: 0.0479, Val Loss: 0.1095, LR: 0.001600
# Epoch 387/2000, Train Loss: 0.0505, Val Loss: 0.0657, LR: 0.001600
# Epoch 388/2000, Train Loss: 0.0501, Val Loss: 0.0366, LR: 0.001600
# Epoch 389/2000, Train Loss: 0.0448, Val Loss: 0.0329, LR: 0.001600
# Epoch 390/2000, Train Loss: 0.0446, Val Loss: 0.0370, LR: 0.001600
# Epoch 391/2000, Train Loss: 0.0484, Val Loss: 0.0468, LR: 0.001600
# Epoch 392/2000, Train Loss: 0.0491, Val Loss: 0.0357, LR: 0.001600
# Epoch 393/2000, Train Loss: 0.0539, Val Loss: 0.0465, LR: 0.001600
# Epoch 394/2000, Train Loss: 0.0491, Val Loss: 0.0550, LR: 0.001600
# Epoch 395/2000, Train Loss: 0.0481, Val Loss: 0.0482, LR: 0.001600
# Epoch 396/2000, Train Loss: 0.0463, Val Loss: 0.0384, LR: 0.001600
# Epoch 397/2000, Train Loss: 0.0457, Val Loss: 0.0405, LR: 0.001600
# Epoch 398/2000, Train Loss: 0.0459, Val Loss: 0.0424, LR: 0.001600
# Epoch 399/2000, Train Loss: 0.0439, Val Loss: 0.0414, LR: 0.001600
# Epoch 400/2000, Train Loss: 0.0479, Val Loss: 0.0279, LR: 0.001280
# Epoch 401/2000, Train Loss: 0.0491, Val Loss: 0.0279, LR: 0.001280
# Epoch 402/2000, Train Loss: 0.0485, Val Loss: 0.0553, LR: 0.001280
# Epoch 403/2000, Train Loss: 0.0484, Val Loss: 0.0568, LR: 0.001280
# Epoch 404/2000, Train Loss: 0.0453, Val Loss: 0.0818, LR: 0.001280
# Epoch 405/2000, Train Loss: 0.0506, Val Loss: 0.0623, LR: 0.001280
# Epoch 406/2000, Train Loss: 0.0566, Val Loss: 0.0276, LR: 0.001280
# Epoch 407/2000, Train Loss: 0.0537, Val Loss: 0.0349, LR: 0.001280
# Epoch 408/2000, Train Loss: 0.0462, Val Loss: 0.0477, LR: 0.001280
# Epoch 409/2000, Train Loss: 0.0479, Val Loss: 0.0286, LR: 0.001280
# Epoch 410/2000, Train Loss: 0.0461, Val Loss: 0.0299, LR: 0.001280
# Epoch 411/2000, Train Loss: 0.0487, Val Loss: 0.0570, LR: 0.001280
# Epoch 412/2000, Train Loss: 0.0484, Val Loss: 0.0325, LR: 0.001280
# Epoch 413/2000, Train Loss: 0.0464, Val Loss: 0.0460, LR: 0.001280
# Epoch 414/2000, Train Loss: 0.0471, Val Loss: 0.0663, LR: 0.001280
# Epoch 415/2000, Train Loss: 0.0463, Val Loss: 0.0529, LR: 0.001280
# Epoch 416/2000, Train Loss: 0.0461, Val Loss: 0.0357, LR: 0.001280
# Epoch 417/2000, Train Loss: 0.0457, Val Loss: 0.0302, LR: 0.001280
# Epoch 418/2000, Train Loss: 0.0488, Val Loss: 0.0288, LR: 0.001280
# Epoch 419/2000, Train Loss: 0.0528, Val Loss: 0.0321, LR: 0.001280
# Epoch 420/2000, Train Loss: 0.0485, Val Loss: 0.0333, LR: 0.001280
# Epoch 421/2000, Train Loss: 0.0459, Val Loss: 0.0334, LR: 0.001280
# Epoch 422/2000, Train Loss: 0.0475, Val Loss: 0.0340, LR: 0.001280
# Epoch 423/2000, Train Loss: 0.0447, Val Loss: 0.0388, LR: 0.001280
# Epoch 424/2000, Train Loss: 0.0451, Val Loss: 0.0422, LR: 0.001280
# Epoch 425/2000, Train Loss: 0.0487, Val Loss: 0.0550, LR: 0.001280
# Epoch 426/2000, Train Loss: 0.0441, Val Loss: 0.0444, LR: 0.001280
# Epoch 427/2000, Train Loss: 0.0423, Val Loss: 0.0332, LR: 0.001280
# Epoch 428/2000, Train Loss: 0.0469, Val Loss: 0.0969, LR: 0.001280
# Epoch 429/2000, Train Loss: 0.0447, Val Loss: 0.0999, LR: 0.001280
# Epoch 430/2000, Train Loss: 0.0541, Val Loss: 0.0957, LR: 0.001280
# Epoch 431/2000, Train Loss: 0.0460, Val Loss: 0.0576, LR: 0.001280
# Epoch 432/2000, Train Loss: 0.0489, Val Loss: 0.0358, LR: 0.001280
# Epoch 433/2000, Train Loss: 0.0437, Val Loss: 0.0413, LR: 0.001280
# Epoch 434/2000, Train Loss: 0.0450, Val Loss: 0.0392, LR: 0.001280
# Epoch 435/2000, Train Loss: 0.0434, Val Loss: 0.0440, LR: 0.001280
# Epoch 436/2000, Train Loss: 0.0441, Val Loss: 0.0348, LR: 0.001280
# Epoch 437/2000, Train Loss: 0.0455, Val Loss: 0.0460, LR: 0.001280
# Epoch 438/2000, Train Loss: 0.0523, Val Loss: 0.0462, LR: 0.001280
# Epoch 439/2000, Train Loss: 0.0467, Val Loss: 0.0576, LR: 0.001280
# Epoch 440/2000, Train Loss: 0.0491, Val Loss: 0.0422, LR: 0.001280
# Epoch 441/2000, Train Loss: 0.0501, Val Loss: 0.0314, LR: 0.001280
# Epoch 442/2000, Train Loss: 0.0442, Val Loss: 0.0291, LR: 0.001280
# Epoch 443/2000, Train Loss: 0.0553, Val Loss: 0.0470, LR: 0.001280
# Epoch 444/2000, Train Loss: 0.0485, Val Loss: 0.0563, LR: 0.001280
# Epoch 445/2000, Train Loss: 0.0503, Val Loss: 0.0607, LR: 0.001280
# Epoch 446/2000, Train Loss: 0.0459, Val Loss: 0.1765, LR: 0.001280
# Epoch 447/2000, Train Loss: 0.0473, Val Loss: 0.0874, LR: 0.001280
# Epoch 448/2000, Train Loss: 0.0475, Val Loss: 0.0765, LR: 0.001280
# Epoch 449/2000, Train Loss: 0.0526, Val Loss: 0.3373, LR: 0.001280
# Epoch 450/2000, Train Loss: 0.0413, Val Loss: 0.0727, LR: 0.001280
# Epoch 451/2000, Train Loss: 0.0438, Val Loss: 0.0325, LR: 0.001280
# Epoch 452/2000, Train Loss: 0.0439, Val Loss: 0.0251, LR: 0.001280
# Epoch 453/2000, Train Loss: 0.0444, Val Loss: 0.0455, LR: 0.001280
# Epoch 454/2000, Train Loss: 0.0424, Val Loss: 0.0229, LR: 0.001280
# Epoch 455/2000, Train Loss: 0.0434, Val Loss: 0.0235, LR: 0.001280
# Epoch 456/2000, Train Loss: 0.0442, Val Loss: 0.0367, LR: 0.001280
# Epoch 457/2000, Train Loss: 0.0485, Val Loss: 0.0841, LR: 0.001280
# Epoch 458/2000, Train Loss: 0.0438, Val Loss: 0.1276, LR: 0.001280
# Epoch 459/2000, Train Loss: 0.0425, Val Loss: 0.0307, LR: 0.001280
# Epoch 460/2000, Train Loss: 0.0420, Val Loss: 0.0242, LR: 0.001280
# Epoch 461/2000, Train Loss: 0.0421, Val Loss: 0.0247, LR: 0.001280
# Epoch 462/2000, Train Loss: 0.0430, Val Loss: 0.0250, LR: 0.001280
# Epoch 463/2000, Train Loss: 0.0429, Val Loss: 0.0429, LR: 0.001280
# Epoch 464/2000, Train Loss: 0.0418, Val Loss: 0.0554, LR: 0.001280
# Epoch 465/2000, Train Loss: 0.0477, Val Loss: 0.0791, LR: 0.001280
# Epoch 466/2000, Train Loss: 0.0420, Val Loss: 0.0569, LR: 0.001280
# Epoch 467/2000, Train Loss: 0.0421, Val Loss: 0.0298, LR: 0.001280
# Epoch 468/2000, Train Loss: 0.0479, Val Loss: 0.0266, LR: 0.001280
# Epoch 469/2000, Train Loss: 0.0469, Val Loss: 0.0260, LR: 0.001280
# Epoch 470/2000, Train Loss: 0.0403, Val Loss: 0.0391, LR: 0.001280
# Epoch 471/2000, Train Loss: 0.0428, Val Loss: 0.0656, LR: 0.001280
# Epoch 472/2000, Train Loss: 0.0488, Val Loss: 0.0614, LR: 0.001280
# Epoch 473/2000, Train Loss: 0.0407, Val Loss: 0.0341, LR: 0.001280
# Epoch 474/2000, Train Loss: 0.0447, Val Loss: 0.0479, LR: 0.001280
# Epoch 475/2000, Train Loss: 0.0474, Val Loss: 0.0525, LR: 0.001280
# Epoch 476/2000, Train Loss: 0.0440, Val Loss: 0.0684, LR: 0.001280
# Epoch 477/2000, Train Loss: 0.0423, Val Loss: 0.0298, LR: 0.001280
# Epoch 478/2000, Train Loss: 0.0427, Val Loss: 0.0292, LR: 0.001280
# Epoch 479/2000, Train Loss: 0.0429, Val Loss: 0.0739, LR: 0.001280
# Epoch 480/2000, Train Loss: 0.0440, Val Loss: 0.1131, LR: 0.001280
# Epoch 481/2000, Train Loss: 0.0420, Val Loss: 0.1516, LR: 0.001280
# Epoch 482/2000, Train Loss: 0.0495, Val Loss: 0.0476, LR: 0.001280
# Epoch 483/2000, Train Loss: 0.0409, Val Loss: 0.0387, LR: 0.001280
# Epoch 484/2000, Train Loss: 0.0397, Val Loss: 0.0579, LR: 0.001280
# Epoch 485/2000, Train Loss: 0.0402, Val Loss: 0.0305, LR: 0.001280
# Epoch 486/2000, Train Loss: 0.0499, Val Loss: 0.0246, LR: 0.001280
# Epoch 487/2000, Train Loss: 0.0409, Val Loss: 0.0234, LR: 0.001280
# Epoch 488/2000, Train Loss: 0.0380, Val Loss: 0.0238, LR: 0.001280
# Epoch 489/2000, Train Loss: 0.0391, Val Loss: 0.0285, LR: 0.001280
# Epoch 490/2000, Train Loss: 0.0401, Val Loss: 0.0258, LR: 0.001280
# Epoch 491/2000, Train Loss: 0.0448, Val Loss: 0.0282, LR: 0.001280
# Epoch 492/2000, Train Loss: 0.0419, Val Loss: 0.0397, LR: 0.001280
# Epoch 493/2000, Train Loss: 0.0422, Val Loss: 0.0268, LR: 0.001280
# Epoch 494/2000, Train Loss: 0.0440, Val Loss: 0.0248, LR: 0.001280
# Epoch 495/2000, Train Loss: 0.0424, Val Loss: 0.0372, LR: 0.001280
# Epoch 496/2000, Train Loss: 0.0419, Val Loss: 0.0416, LR: 0.001280
# Epoch 497/2000, Train Loss: 0.0405, Val Loss: 0.0351, LR: 0.001280
# Epoch 498/2000, Train Loss: 0.0414, Val Loss: 0.0411, LR: 0.001280
# Epoch 499/2000, Train Loss: 0.0399, Val Loss: 0.0337, LR: 0.001280
# Epoch 500/2000, Train Loss: 0.0407, Val Loss: 0.0350, LR: 0.001280
# Epoch 501/2000, Train Loss: 0.0428, Val Loss: 0.0359, LR: 0.001280
# Epoch 502/2000, Train Loss: 0.0377, Val Loss: 0.0281, LR: 0.001280
# Epoch 503/2000, Train Loss: 0.0402, Val Loss: 0.0291, LR: 0.001280
# Epoch 504/2000, Train Loss: 0.0413, Val Loss: 0.0326, LR: 0.001280
# Epoch 505/2000, Train Loss: 0.0407, Val Loss: 0.0308, LR: 0.001280
# Epoch 506/2000, Train Loss: 0.0385, Val Loss: 0.0402, LR: 0.001280
# Epoch 507/2000, Train Loss: 0.0407, Val Loss: 0.0670, LR: 0.001280
# Epoch 508/2000, Train Loss: 0.0394, Val Loss: 0.0513, LR: 0.001280
# Epoch 509/2000, Train Loss: 0.0419, Val Loss: 0.0272, LR: 0.001280
# Epoch 510/2000, Train Loss: 0.0454, Val Loss: 0.0236, LR: 0.001280
# Epoch 511/2000, Train Loss: 0.0411, Val Loss: 0.0219, LR: 0.001280
# Epoch 512/2000, Train Loss: 0.0392, Val Loss: 0.0310, LR: 0.001280
# Epoch 513/2000, Train Loss: 0.0387, Val Loss: 0.0215, LR: 0.001280
# Epoch 514/2000, Train Loss: 0.0378, Val Loss: 0.0188, LR: 0.001280
# Epoch 515/2000, Train Loss: 0.0397, Val Loss: 0.0315, LR: 0.001280
# Epoch 516/2000, Train Loss: 0.0388, Val Loss: 0.0434, LR: 0.001280
# Epoch 517/2000, Train Loss: 0.0417, Val Loss: 0.0406, LR: 0.001280
# Epoch 518/2000, Train Loss: 0.0387, Val Loss: 0.0305, LR: 0.001280
# Epoch 519/2000, Train Loss: 0.0403, Val Loss: 0.0342, LR: 0.001280
# Epoch 520/2000, Train Loss: 0.0412, Val Loss: 0.0308, LR: 0.001280
# Epoch 521/2000, Train Loss: 0.0374, Val Loss: 0.0295, LR: 0.001280
# Epoch 522/2000, Train Loss: 0.0432, Val Loss: 0.0404, LR: 0.001280
# Epoch 523/2000, Train Loss: 0.0371, Val Loss: 0.0321, LR: 0.001280
# Epoch 524/2000, Train Loss: 0.0425, Val Loss: 0.0273, LR: 0.001280
# Epoch 525/2000, Train Loss: 0.0395, Val Loss: 0.0246, LR: 0.001280
# Epoch 526/2000, Train Loss: 0.0405, Val Loss: 0.0423, LR: 0.001280
# Epoch 527/2000, Train Loss: 0.0413, Val Loss: 0.0552, LR: 0.001280
# Epoch 528/2000, Train Loss: 0.0413, Val Loss: 0.0732, LR: 0.001280
# Epoch 529/2000, Train Loss: 0.0362, Val Loss: 0.1071, LR: 0.001280
# Epoch 530/2000, Train Loss: 0.0377, Val Loss: 0.0453, LR: 0.001280
# Epoch 531/2000, Train Loss: 0.0386, Val Loss: 0.0419, LR: 0.001280
# Epoch 532/2000, Train Loss: 0.0395, Val Loss: 0.0249, LR: 0.001280
# Epoch 533/2000, Train Loss: 0.0406, Val Loss: 0.0181, LR: 0.001280
# Epoch 534/2000, Train Loss: 0.0380, Val Loss: 0.0175, LR: 0.001280
# Epoch 535/2000, Train Loss: 0.0415, Val Loss: 0.0204, LR: 0.001280
# Epoch 536/2000, Train Loss: 0.0382, Val Loss: 0.0359, LR: 0.001280
# Epoch 537/2000, Train Loss: 0.0368, Val Loss: 0.0246, LR: 0.001280
# Epoch 538/2000, Train Loss: 0.0380, Val Loss: 0.0328, LR: 0.001280
# Epoch 539/2000, Train Loss: 0.0365, Val Loss: 0.0383, LR: 0.001280
# Epoch 540/2000, Train Loss: 0.0366, Val Loss: 0.0419, LR: 0.001280
# Epoch 541/2000, Train Loss: 0.0361, Val Loss: 0.0318, LR: 0.001280
# Epoch 542/2000, Train Loss: 0.0371, Val Loss: 0.0268, LR: 0.001280
# Epoch 543/2000, Train Loss: 0.0448, Val Loss: 0.0195, LR: 0.001280
# Epoch 544/2000, Train Loss: 0.0385, Val Loss: 0.0190, LR: 0.001280
# Epoch 545/2000, Train Loss: 0.0393, Val Loss: 0.0219, LR: 0.001280
# Epoch 546/2000, Train Loss: 0.0388, Val Loss: 0.0351, LR: 0.001280
# Epoch 547/2000, Train Loss: 0.0376, Val Loss: 0.0201, LR: 0.001280
# Epoch 548/2000, Train Loss: 0.0391, Val Loss: 0.0150, LR: 0.001280
# Epoch 549/2000, Train Loss: 0.0397, Val Loss: 0.0149, LR: 0.001280
# Epoch 550/2000, Train Loss: 0.0381, Val Loss: 0.0234, LR: 0.001280
# Epoch 551/2000, Train Loss: 0.0372, Val Loss: 0.0252, LR: 0.001280
# Epoch 552/2000, Train Loss: 0.0394, Val Loss: 0.0316, LR: 0.001280
# Epoch 553/2000, Train Loss: 0.0387, Val Loss: 0.0520, LR: 0.001280
# Epoch 554/2000, Train Loss: 0.0350, Val Loss: 0.0230, LR: 0.001280
# Epoch 555/2000, Train Loss: 0.0378, Val Loss: 0.0186, LR: 0.001280
# Epoch 556/2000, Train Loss: 0.0374, Val Loss: 0.0254, LR: 0.001280
# Epoch 557/2000, Train Loss: 0.0353, Val Loss: 0.0230, LR: 0.001280
# Epoch 558/2000, Train Loss: 0.0367, Val Loss: 0.0359, LR: 0.001280
# Epoch 559/2000, Train Loss: 0.0361, Val Loss: 0.0459, LR: 0.001280
# Epoch 560/2000, Train Loss: 0.0379, Val Loss: 0.0469, LR: 0.001280
# Epoch 561/2000, Train Loss: 0.0325, Val Loss: 0.0300, LR: 0.001280
# Epoch 562/2000, Train Loss: 0.0366, Val Loss: 0.0176, LR: 0.001280
# Epoch 563/2000, Train Loss: 0.0345, Val Loss: 0.0652, LR: 0.001280
# Epoch 564/2000, Train Loss: 0.0355, Val Loss: 0.0483, LR: 0.001280
# Epoch 565/2000, Train Loss: 0.0373, Val Loss: 0.0660, LR: 0.001280
# Epoch 566/2000, Train Loss: 0.0352, Val Loss: 0.1259, LR: 0.001280
# Epoch 567/2000, Train Loss: 0.0361, Val Loss: 0.0439, LR: 0.001280
# Epoch 568/2000, Train Loss: 0.0361, Val Loss: 0.0178, LR: 0.001280
# Epoch 569/2000, Train Loss: 0.0340, Val Loss: 0.0235, LR: 0.001280
# Epoch 570/2000, Train Loss: 0.0364, Val Loss: 0.0201, LR: 0.001280
# Epoch 571/2000, Train Loss: 0.0371, Val Loss: 0.0155, LR: 0.001280
# Epoch 572/2000, Train Loss: 0.0361, Val Loss: 0.0294, LR: 0.001280
# Epoch 573/2000, Train Loss: 0.0356, Val Loss: 0.0451, LR: 0.001280
# Epoch 574/2000, Train Loss: 0.0359, Val Loss: 0.0656, LR: 0.001280
# Epoch 575/2000, Train Loss: 0.0368, Val Loss: 0.0320, LR: 0.001280
# Epoch 576/2000, Train Loss: 0.0376, Val Loss: 0.0201, LR: 0.001280
# Epoch 577/2000, Train Loss: 0.0366, Val Loss: 0.0227, LR: 0.001280
# Epoch 578/2000, Train Loss: 0.0396, Val Loss: 0.0372, LR: 0.001280
# Epoch 579/2000, Train Loss: 0.0322, Val Loss: 0.0317, LR: 0.001280
# Epoch 580/2000, Train Loss: 0.0360, Val Loss: 0.0311, LR: 0.001280
# Epoch 581/2000, Train Loss: 0.0369, Val Loss: 0.0187, LR: 0.001280
# Epoch 582/2000, Train Loss: 0.0328, Val Loss: 0.0271, LR: 0.001280
# Epoch 583/2000, Train Loss: 0.0369, Val Loss: 0.0204, LR: 0.001280
# Epoch 584/2000, Train Loss: 0.0380, Val Loss: 0.0203, LR: 0.001280
# Epoch 585/2000, Train Loss: 0.0335, Val Loss: 0.0198, LR: 0.001280
# Epoch 586/2000, Train Loss: 0.0350, Val Loss: 0.0185, LR: 0.001280
# Epoch 587/2000, Train Loss: 0.0333, Val Loss: 0.0164, LR: 0.001280
# Epoch 588/2000, Train Loss: 0.0393, Val Loss: 0.0622, LR: 0.001280
# Epoch 589/2000, Train Loss: 0.0313, Val Loss: 0.1112, LR: 0.001280
# Epoch 590/2000, Train Loss: 0.0348, Val Loss: 0.0661, LR: 0.001280
# Epoch 591/2000, Train Loss: 0.0330, Val Loss: 0.0362, LR: 0.001280
# Epoch 592/2000, Train Loss: 0.0331, Val Loss: 0.0189, LR: 0.001280
# Epoch 593/2000, Train Loss: 0.0379, Val Loss: 0.0211, LR: 0.001280
# Epoch 594/2000, Train Loss: 0.0343, Val Loss: 0.0317, LR: 0.001280
# Epoch 595/2000, Train Loss: 0.0381, Val Loss: 0.0260, LR: 0.001280
# Epoch 596/2000, Train Loss: 0.0340, Val Loss: 0.0550, LR: 0.001280
# Epoch 597/2000, Train Loss: 0.0364, Val Loss: 0.0450, LR: 0.001280
# Epoch 598/2000, Train Loss: 0.0335, Val Loss: 0.0511, LR: 0.001280
# Epoch 599/2000, Train Loss: 0.0384, Val Loss: 0.0434, LR: 0.001280
# Epoch 600/2000, Train Loss: 0.0351, Val Loss: 0.0212, LR: 0.001024
# Epoch 601/2000, Train Loss: 0.0375, Val Loss: 0.0183, LR: 0.001024
# Epoch 602/2000, Train Loss: 0.0346, Val Loss: 0.0153, LR: 0.001024
# Epoch 603/2000, Train Loss: 0.0322, Val Loss: 0.0164, LR: 0.001024
# Epoch 604/2000, Train Loss: 0.0318, Val Loss: 0.0287, LR: 0.001024
# Epoch 605/2000, Train Loss: 0.0314, Val Loss: 0.0449, LR: 0.001024
# Epoch 606/2000, Train Loss: 0.0339, Val Loss: 0.0489, LR: 0.001024
# Epoch 607/2000, Train Loss: 0.0384, Val Loss: 0.0399, LR: 0.001024
# Epoch 608/2000, Train Loss: 0.0348, Val Loss: 0.0302, LR: 0.001024
# Epoch 609/2000, Train Loss: 0.0321, Val Loss: 0.0307, LR: 0.001024
# Epoch 610/2000, Train Loss: 0.0343, Val Loss: 0.0374, LR: 0.001024
# Epoch 611/2000, Train Loss: 0.0335, Val Loss: 0.0219, LR: 0.001024
# Epoch 612/2000, Train Loss: 0.0343, Val Loss: 0.0316, LR: 0.001024
# Epoch 613/2000, Train Loss: 0.0335, Val Loss: 0.0447, LR: 0.001024
# Epoch 614/2000, Train Loss: 0.0321, Val Loss: 0.0373, LR: 0.001024
# Epoch 615/2000, Train Loss: 0.0321, Val Loss: 0.0579, LR: 0.001024
# Epoch 616/2000, Train Loss: 0.0325, Val Loss: 0.0306, LR: 0.001024
# Epoch 617/2000, Train Loss: 0.0337, Val Loss: 0.0257, LR: 0.001024
# Epoch 618/2000, Train Loss: 0.0326, Val Loss: 0.0221, LR: 0.001024
# Epoch 619/2000, Train Loss: 0.0313, Val Loss: 0.0243, LR: 0.001024
# Epoch 620/2000, Train Loss: 0.0311, Val Loss: 0.0236, LR: 0.001024
# Epoch 621/2000, Train Loss: 0.0326, Val Loss: 0.0389, LR: 0.001024
# Epoch 622/2000, Train Loss: 0.0324, Val Loss: 0.0311, LR: 0.001024
# Epoch 623/2000, Train Loss: 0.0355, Val Loss: 0.0222, LR: 0.001024
# Epoch 624/2000, Train Loss: 0.0342, Val Loss: 0.0422, LR: 0.001024
# Epoch 625/2000, Train Loss: 0.0312, Val Loss: 0.0245, LR: 0.001024
# Epoch 626/2000, Train Loss: 0.0326, Val Loss: 0.0165, LR: 0.001024
# Epoch 627/2000, Train Loss: 0.0304, Val Loss: 0.0248, LR: 0.001024
# Epoch 628/2000, Train Loss: 0.0319, Val Loss: 0.0169, LR: 0.001024
# Epoch 629/2000, Train Loss: 0.0346, Val Loss: 0.0117, LR: 0.001024
# Epoch 630/2000, Train Loss: 0.0327, Val Loss: 0.0218, LR: 0.001024
# Epoch 631/2000, Train Loss: 0.0308, Val Loss: 0.0224, LR: 0.001024
# Epoch 632/2000, Train Loss: 0.0308, Val Loss: 0.0199, LR: 0.001024
# Epoch 633/2000, Train Loss: 0.0314, Val Loss: 0.0186, LR: 0.001024
# Epoch 634/2000, Train Loss: 0.0310, Val Loss: 0.0326, LR: 0.001024
# Epoch 635/2000, Train Loss: 0.0320, Val Loss: 0.0393, LR: 0.001024
# Epoch 636/2000, Train Loss: 0.0341, Val Loss: 0.0201, LR: 0.001024
# Epoch 637/2000, Train Loss: 0.0308, Val Loss: 0.0259, LR: 0.001024
# Epoch 638/2000, Train Loss: 0.0309, Val Loss: 0.0209, LR: 0.001024
# Epoch 639/2000, Train Loss: 0.0324, Val Loss: 0.0218, LR: 0.001024
# Epoch 640/2000, Train Loss: 0.0342, Val Loss: 0.0160, LR: 0.001024
# Epoch 641/2000, Train Loss: 0.0364, Val Loss: 0.0157, LR: 0.001024
# Epoch 642/2000, Train Loss: 0.0302, Val Loss: 0.0218, LR: 0.001024
# Epoch 643/2000, Train Loss: 0.0279, Val Loss: 0.0193, LR: 0.001024
# Epoch 644/2000, Train Loss: 0.0312, Val Loss: 0.0219, LR: 0.001024
# Epoch 645/2000, Train Loss: 0.0306, Val Loss: 0.0192, LR: 0.001024
# Epoch 646/2000, Train Loss: 0.0316, Val Loss: 0.0278, LR: 0.001024
# Epoch 647/2000, Train Loss: 0.0316, Val Loss: 0.0240, LR: 0.001024
# Epoch 648/2000, Train Loss: 0.0304, Val Loss: 0.0196, LR: 0.001024
# Epoch 649/2000, Train Loss: 0.0288, Val Loss: 0.0182, LR: 0.001024
# Epoch 650/2000, Train Loss: 0.0313, Val Loss: 0.0227, LR: 0.001024
# Epoch 651/2000, Train Loss: 0.0336, Val Loss: 0.0218, LR: 0.001024
# Epoch 652/2000, Train Loss: 0.0334, Val Loss: 0.0232, LR: 0.001024
# Epoch 653/2000, Train Loss: 0.0303, Val Loss: 0.0683, LR: 0.001024
# Epoch 654/2000, Train Loss: 0.0298, Val Loss: 0.0335, LR: 0.001024
# Epoch 655/2000, Train Loss: 0.0333, Val Loss: 0.0485, LR: 0.001024
# Epoch 656/2000, Train Loss: 0.0291, Val Loss: 0.0424, LR: 0.001024
# Epoch 657/2000, Train Loss: 0.0319, Val Loss: 0.0211, LR: 0.001024
# Epoch 658/2000, Train Loss: 0.0321, Val Loss: 0.0208, LR: 0.001024
# Epoch 659/2000, Train Loss: 0.0294, Val Loss: 0.0142, LR: 0.001024
# Epoch 660/2000, Train Loss: 0.0289, Val Loss: 0.0129, LR: 0.001024
# Epoch 661/2000, Train Loss: 0.0303, Val Loss: 0.0132, LR: 0.001024
# Epoch 662/2000, Train Loss: 0.0325, Val Loss: 0.0092, LR: 0.001024
# Epoch 663/2000, Train Loss: 0.0292, Val Loss: 0.0165, LR: 0.001024
# Epoch 664/2000, Train Loss: 0.0301, Val Loss: 0.0254, LR: 0.001024
# Epoch 665/2000, Train Loss: 0.0300, Val Loss: 0.0097, LR: 0.001024
# Epoch 666/2000, Train Loss: 0.0295, Val Loss: 0.0095, LR: 0.001024
# Epoch 667/2000, Train Loss: 0.0298, Val Loss: 0.0113, LR: 0.001024
# Epoch 668/2000, Train Loss: 0.0310, Val Loss: 0.0156, LR: 0.001024
# Epoch 669/2000, Train Loss: 0.0289, Val Loss: 0.0307, LR: 0.001024
# Epoch 670/2000, Train Loss: 0.0305, Val Loss: 0.0201, LR: 0.001024
# Epoch 671/2000, Train Loss: 0.0306, Val Loss: 0.0208, LR: 0.001024
# Epoch 672/2000, Train Loss: 0.0301, Val Loss: 0.0196, LR: 0.001024
# Epoch 673/2000, Train Loss: 0.0293, Val Loss: 0.0161, LR: 0.001024
# Epoch 674/2000, Train Loss: 0.0331, Val Loss: 0.0277, LR: 0.001024
# Epoch 675/2000, Train Loss: 0.0316, Val Loss: 0.0332, LR: 0.001024
# Epoch 676/2000, Train Loss: 0.0302, Val Loss: 0.0251, LR: 0.001024
# Epoch 677/2000, Train Loss: 0.0283, Val Loss: 0.0216, LR: 0.001024
# Epoch 678/2000, Train Loss: 0.0281, Val Loss: 0.0355, LR: 0.001024
# Epoch 679/2000, Train Loss: 0.0307, Val Loss: 0.0415, LR: 0.001024
# Epoch 680/2000, Train Loss: 0.0282, Val Loss: 0.0257, LR: 0.001024
# Epoch 681/2000, Train Loss: 0.0280, Val Loss: 0.0162, LR: 0.001024
# Epoch 682/2000, Train Loss: 0.0331, Val Loss: 0.0153, LR: 0.001024
# Epoch 683/2000, Train Loss: 0.0271, Val Loss: 0.0152, LR: 0.001024
# Epoch 684/2000, Train Loss: 0.0305, Val Loss: 0.0096, LR: 0.001024
# Epoch 685/2000, Train Loss: 0.0285, Val Loss: 0.0135, LR: 0.001024
# Epoch 686/2000, Train Loss: 0.0276, Val Loss: 0.0313, LR: 0.001024
# Epoch 687/2000, Train Loss: 0.0281, Val Loss: 0.0659, LR: 0.001024
# Epoch 688/2000, Train Loss: 0.0279, Val Loss: 0.0755, LR: 0.001024
# Epoch 689/2000, Train Loss: 0.0280, Val Loss: 0.0452, LR: 0.001024
# Epoch 690/2000, Train Loss: 0.0258, Val Loss: 0.0347, LR: 0.001024
# Epoch 691/2000, Train Loss: 0.0282, Val Loss: 0.0260, LR: 0.001024
# Epoch 692/2000, Train Loss: 0.0287, Val Loss: 0.0178, LR: 0.001024
# Epoch 693/2000, Train Loss: 0.0275, Val Loss: 0.0122, LR: 0.001024
# Epoch 694/2000, Train Loss: 0.0265, Val Loss: 0.0173, LR: 0.001024
# Epoch 695/2000, Train Loss: 0.0286, Val Loss: 0.0114, LR: 0.001024
# Epoch 696/2000, Train Loss: 0.0309, Val Loss: 0.0095, LR: 0.001024
# Epoch 697/2000, Train Loss: 0.0294, Val Loss: 0.0223, LR: 0.001024
# Epoch 698/2000, Train Loss: 0.0285, Val Loss: 0.0198, LR: 0.001024
# Epoch 699/2000, Train Loss: 0.0304, Val Loss: 0.0121, LR: 0.001024
# Epoch 700/2000, Train Loss: 0.0264, Val Loss: 0.0258, LR: 0.001024
# Epoch 701/2000, Train Loss: 0.0272, Val Loss: 0.0213, LR: 0.001024
# Epoch 702/2000, Train Loss: 0.0275, Val Loss: 0.0225, LR: 0.001024
# Epoch 703/2000, Train Loss: 0.0291, Val Loss: 0.0204, LR: 0.001024
# Epoch 704/2000, Train Loss: 0.0259, Val Loss: 0.0183, LR: 0.001024
# Epoch 705/2000, Train Loss: 0.0267, Val Loss: 0.0539, LR: 0.001024
# Epoch 706/2000, Train Loss: 0.0278, Val Loss: 0.0570, LR: 0.001024
# Epoch 707/2000, Train Loss: 0.0293, Val Loss: 0.0309, LR: 0.001024
# Epoch 708/2000, Train Loss: 0.0276, Val Loss: 0.0290, LR: 0.001024
# Epoch 709/2000, Train Loss: 0.0272, Val Loss: 0.0369, LR: 0.001024
# Epoch 710/2000, Train Loss: 0.0274, Val Loss: 0.0452, LR: 0.001024
# Epoch 711/2000, Train Loss: 0.0272, Val Loss: 0.0374, LR: 0.001024
# Epoch 712/2000, Train Loss: 0.0262, Val Loss: 0.0401, LR: 0.001024
# Epoch 713/2000, Train Loss: 0.0256, Val Loss: 0.0205, LR: 0.001024
# Epoch 714/2000, Train Loss: 0.0277, Val Loss: 0.0172, LR: 0.001024
# Epoch 715/2000, Train Loss: 0.0285, Val Loss: 0.0166, LR: 0.001024
# Epoch 716/2000, Train Loss: 0.0287, Val Loss: 0.0307, LR: 0.001024
# Epoch 717/2000, Train Loss: 0.0270, Val Loss: 0.0341, LR: 0.001024
# ...
# Epoch 719/2000, Train Loss: 0.0240, Val Loss: 0.0583, LR: 0.001024
# Epoch 720/2000, Train Loss: 0.0288, Val Loss: 0.0436, LR: 0.001024
# Epoch 721/2000, Train Loss: 0.0259, Val Loss: 0.0545, LR: 0.001024
# Epoch 722/2000, Train Loss: 0.0244, Val Loss: 0.0469, LR: 0.001024
# Epoch 723/2000, Train Loss: 0.0238, Val Loss: 0.0353, LR: 0.001024
# Epoch 724/2000, Train Loss: 0.0245, Val Loss: 0.0289, LR: 0.001024
# Epoch 725/2000, Train Loss: 0.0272, Val Loss: 0.0228, LR: 0.001024
# Epoch 726/2000, Train Loss: 0.0271, Val Loss: 0.0527, LR: 0.001024
# Epoch 727/2000, Train Loss: 0.0272, Val Loss: 0.0372, LR: 0.001024
# Epoch 728/2000, Train Loss: 0.0276, Val Loss: 0.0212, LR: 0.001024
# Epoch 729/2000, Train Loss: 0.0268, Val Loss: 0.0224, LR: 0.001024
# Epoch 730/2000, Train Loss: 0.0268, Val Loss: 0.0186, LR: 0.001024
# Epoch 731/2000, Train Loss: 0.0255, Val Loss: 0.0201, LR: 0.001024
# Epoch 732/2000, Train Loss: 0.0261, Val Loss: 0.0352, LR: 0.001024
# Epoch 733/2000, Train Loss: 0.0276, Val Loss: 0.0853, LR: 0.001024
# Epoch 734/2000, Train Loss: 0.0258, Val Loss: 0.0624, LR: 0.001024
# Epoch 735/2000, Train Loss: 0.0287, Val Loss: 0.0324, LR: 0.001024
# Epoch 736/2000, Train Loss: 0.0254, Val Loss: 0.0393, LR: 0.001024
# Epoch 737/2000, Train Loss: 0.0265, Val Loss: 0.0158, LR: 0.001024
# Epoch 738/2000, Train Loss: 0.0274, Val Loss: 0.0097, LR: 0.001024
# Epoch 739/2000, Train Loss: 0.0260, Val Loss: 0.0299, LR: 0.001024
# Epoch 740/2000, Train Loss: 0.0249, Val Loss: 0.0318, LR: 0.001024
# Epoch 741/2000, Train Loss: 0.0254, Val Loss: 0.0272, LR: 0.001024
# Epoch 742/2000, Train Loss: 0.0258, Val Loss: 0.0223, LR: 0.001024
# Epoch 743/2000, Train Loss: 0.0268, Val Loss: 0.0267, LR: 0.001024
# Epoch 744/2000, Train Loss: 0.0258, Val Loss: 0.0355, LR: 0.001024
# Epoch 745/2000, Train Loss: 0.0273, Val Loss: 0.0134, LR: 0.001024
# Epoch 746/2000, Train Loss: 0.0283, Val Loss: 0.0100, LR: 0.001024
# Epoch 747/2000, Train Loss: 0.0228, Val Loss: 0.0084, LR: 0.001024
# Epoch 748/2000, Train Loss: 0.0243, Val Loss: 0.0528, LR: 0.001024
# Epoch 749/2000, Train Loss: 0.0274, Val Loss: 0.0071, LR: 0.001024
# Epoch 750/2000, Train Loss: 0.0227, Val Loss: 0.0083, LR: 0.001024
# Epoch 751/2000, Train Loss: 0.0244, Val Loss: 0.0113, LR: 0.001024
# Epoch 752/2000, Train Loss: 0.0245, Val Loss: 0.0213, LR: 0.001024
# Epoch 753/2000, Train Loss: 0.0240, Val Loss: 0.0208, LR: 0.001024
# Epoch 754/2000, Train Loss: 0.0249, Val Loss: 0.0429, LR: 0.001024
# Epoch 755/2000, Train Loss: 0.0257, Val Loss: 0.0242, LR: 0.001024
# Epoch 756/2000, Train Loss: 0.0285, Val Loss: 0.0403, LR: 0.001024
# Epoch 757/2000, Train Loss: 0.0266, Val Loss: 0.0458, LR: 0.001024
# Epoch 758/2000, Train Loss: 0.0244, Val Loss: 0.0207, LR: 0.001024
# Epoch 759/2000, Train Loss: 0.0236, Val Loss: 0.0354, LR: 0.001024
# Epoch 760/2000, Train Loss: 0.0245, Val Loss: 0.0148, LR: 0.001024
# Epoch 761/2000, Train Loss: 0.0226, Val Loss: 0.0098, LR: 0.001024
# Epoch 762/2000, Train Loss: 0.0251, Val Loss: 0.0286, LR: 0.001024
# Epoch 763/2000, Train Loss: 0.0270, Val Loss: 0.0362, LR: 0.001024
# Epoch 764/2000, Train Loss: 0.0234, Val Loss: 0.0529, LR: 0.001024
# Epoch 765/2000, Train Loss: 0.0245, Val Loss: 0.0273, LR: 0.001024
# Epoch 766/2000, Train Loss: 0.0239, Val Loss: 0.0121, LR: 0.001024
# Epoch 767/2000, Train Loss: 0.0224, Val Loss: 0.0299, LR: 0.001024
# Epoch 768/2000, Train Loss: 0.0260, Val Loss: 0.0944, LR: 0.001024
# Epoch 769/2000, Train Loss: 0.0233, Val Loss: 0.0759, LR: 0.001024
# Epoch 770/2000, Train Loss: 0.0253, Val Loss: 0.0434, LR: 0.001024
# Epoch 771/2000, Train Loss: 0.0235, Val Loss: 0.0213, LR: 0.001024
# Epoch 772/2000, Train Loss: 0.0228, Val Loss: 0.0158, LR: 0.001024
# Epoch 773/2000, Train Loss: 0.0247, Val Loss: 0.0241, LR: 0.001024
# Epoch 774/2000, Train Loss: 0.0240, Val Loss: 0.0692, LR: 0.001024
# Epoch 775/2000, Train Loss: 0.0242, Val Loss: 0.0466, LR: 0.001024
# Epoch 776/2000, Train Loss: 0.0241, Val Loss: 0.0256, LR: 0.001024
# Epoch 777/2000, Train Loss: 0.0245, Val Loss: 0.0188, LR: 0.001024
# Epoch 778/2000, Train Loss: 0.0244, Val Loss: 0.0178, LR: 0.001024
# Epoch 779/2000, Train Loss: 0.0229, Val Loss: 0.0229, LR: 0.001024
# Epoch 780/2000, Train Loss: 0.0226, Val Loss: 0.0265, LR: 0.001024
# Epoch 781/2000, Train Loss: 0.0220, Val Loss: 0.0426, LR: 0.001024
# Epoch 782/2000, Train Loss: 0.0224, Val Loss: 0.0370, LR: 0.001024
# Epoch 783/2000, Train Loss: 0.0233, Val Loss: 0.0357, LR: 0.001024
# Epoch 784/2000, Train Loss: 0.0228, Val Loss: 0.0239, LR: 0.001024
# Epoch 785/2000, Train Loss: 0.0245, Val Loss: 0.0543, LR: 0.001024
# Epoch 786/2000, Train Loss: 0.0198, Val Loss: 0.0289, LR: 0.001024
# Epoch 787/2000, Train Loss: 0.0250, Val Loss: 0.0306, LR: 0.001024
# Epoch 788/2000, Train Loss: 0.0228, Val Loss: 0.0132, LR: 0.001024
# Epoch 789/2000, Train Loss: 0.0222, Val Loss: 0.0308, LR: 0.001024
# Epoch 790/2000, Train Loss: 0.0244, Val Loss: 0.0430, LR: 0.001024
# Epoch 791/2000, Train Loss: 0.0228, Val Loss: 0.0295, LR: 0.001024
# Epoch 792/2000, Train Loss: 0.0231, Val Loss: 0.0128, LR: 0.001024
# Epoch 793/2000, Train Loss: 0.0212, Val Loss: 0.0108, LR: 0.001024
# Epoch 794/2000, Train Loss: 0.0234, Val Loss: 0.0330, LR: 0.001024
# Epoch 795/2000, Train Loss: 0.0223, Val Loss: 0.0230, LR: 0.001024
# Epoch 796/2000, Train Loss: 0.0230, Val Loss: 0.0066, LR: 0.001024
# Epoch 797/2000, Train Loss: 0.0230, Val Loss: 0.0060, LR: 0.001024
# Epoch 798/2000, Train Loss: 0.0220, Val Loss: 0.0235, LR: 0.001024
# Epoch 799/2000, Train Loss: 0.0206, Val Loss: 0.0325, LR: 0.001024
# Epoch 800/2000, Train Loss: 0.0221, Val Loss: 0.0214, LR: 0.000819
# Epoch 801/2000, Train Loss: 0.0233, Val Loss: 0.0140, LR: 0.000819
# Epoch 802/2000, Train Loss: 0.0220, Val Loss: 0.0226, LR: 0.000819
# Epoch 803/2000, Train Loss: 0.0231, Val Loss: 0.0189, LR: 0.000819
# Epoch 804/2000, Train Loss: 0.0211, Val Loss: 0.0551, LR: 0.000819
# Epoch 805/2000, Train Loss: 0.0222, Val Loss: 0.0597, LR: 0.000819
# Epoch 806/2000, Train Loss: 0.0200, Val Loss: 0.0327, LR: 0.000819
# Epoch 807/2000, Train Loss: 0.0224, Val Loss: 0.0293, LR: 0.000819
# Epoch 808/2000, Train Loss: 0.0227, Val Loss: 0.0181, LR: 0.000819
# Epoch 809/2000, Train Loss: 0.0211, Val Loss: 0.0312, LR: 0.000819
# Epoch 810/2000, Train Loss: 0.0210, Val Loss: 0.0161, LR: 0.000819
# Epoch 811/2000, Train Loss: 0.0218, Val Loss: 0.0200, LR: 0.000819
# Epoch 812/2000, Train Loss: 0.0216, Val Loss: 0.0208, LR: 0.000819
# Epoch 813/2000, Train Loss: 0.0282, Val Loss: 0.0160, LR: 0.000819
# Epoch 814/2000, Train Loss: 0.0259, Val Loss: 0.0218, LR: 0.000819
# Epoch 815/2000, Train Loss: 0.0223, Val Loss: 0.0081, LR: 0.000819
# Epoch 816/2000, Train Loss: 0.0228, Val Loss: 0.0121, LR: 0.000819
# Epoch 817/2000, Train Loss: 0.0206, Val Loss: 0.0267, LR: 0.000819
# Epoch 818/2000, Train Loss: 0.0198, Val Loss: 0.0193, LR: 0.000819
# Epoch 819/2000, Train Loss: 0.0212, Val Loss: 0.0065, LR: 0.000819
# Epoch 820/2000, Train Loss: 0.0225, Val Loss: 0.0070, LR: 0.000819
# Epoch 821/2000, Train Loss: 0.0211, Val Loss: 0.0192, LR: 0.000819
# Epoch 822/2000, Train Loss: 0.0222, Val Loss: 0.0434, LR: 0.000819
# Epoch 823/2000, Train Loss: 0.0215, Val Loss: 0.0247, LR: 0.000819
# Epoch 824/2000, Train Loss: 0.0213, Val Loss: 0.0266, LR: 0.000819
# Epoch 825/2000, Train Loss: 0.0227, Val Loss: 0.0191, LR: 0.000819
# Epoch 826/2000, Train Loss: 0.0229, Val Loss: 0.0089, LR: 0.000819
# Epoch 827/2000, Train Loss: 0.0245, Val Loss: 0.0080, LR: 0.000819
# Epoch 828/2000, Train Loss: 0.0205, Val Loss: 0.0051, LR: 0.000819
# Epoch 829/2000, Train Loss: 0.0221, Val Loss: 0.0088, LR: 0.000819
# Epoch 830/2000, Train Loss: 0.0215, Val Loss: 0.0182, LR: 0.000819
# Epoch 831/2000, Train Loss: 0.0220, Val Loss: 0.0240, LR: 0.000819
# Epoch 832/2000, Train Loss: 0.0227, Val Loss: 0.0729, LR: 0.000819
# Epoch 833/2000, Train Loss: 0.0229, Val Loss: 0.0311, LR: 0.000819
# Epoch 834/2000, Train Loss: 0.0225, Val Loss: 0.0525, LR: 0.000819
# Epoch 835/2000, Train Loss: 0.0198, Val Loss: 0.0334, LR: 0.000819
# Epoch 836/2000, Train Loss: 0.0189, Val Loss: 0.0087, LR: 0.000819
# Epoch 837/2000, Train Loss: 0.0203, Val Loss: 0.0070, LR: 0.000819
# Epoch 838/2000, Train Loss: 0.0224, Val Loss: 0.0177, LR: 0.000819
# Epoch 839/2000, Train Loss: 0.0212, Val Loss: 0.0159, LR: 0.000819
# Epoch 840/2000, Train Loss: 0.0233, Val Loss: 0.0200, LR: 0.000819
# Epoch 841/2000, Train Loss: 0.0185, Val Loss: 0.0356, LR: 0.000819
# Epoch 842/2000, Train Loss: 0.0197, Val Loss: 0.0268, LR: 0.000819
# Epoch 843/2000, Train Loss: 0.0206, Val Loss: 0.0238, LR: 0.000819
# Epoch 844/2000, Train Loss: 0.0221, Val Loss: 0.0087, LR: 0.000819
# Epoch 845/2000, Train Loss: 0.0197, Val Loss: 0.0068, LR: 0.000819
# Epoch 846/2000, Train Loss: 0.0209, Val Loss: 0.0093, LR: 0.000819
# Epoch 847/2000, Train Loss: 0.0226, Val Loss: 0.0143, LR: 0.000819
# Epoch 848/2000, Train Loss: 0.0231, Val Loss: 0.0229, LR: 0.000819
# Epoch 849/2000, Train Loss: 0.0224, Val Loss: 0.0112, LR: 0.000819
# Epoch 850/2000, Train Loss: 0.0230, Val Loss: 0.0213, LR: 0.000819
# Epoch 851/2000, Train Loss: 0.0225, Val Loss: 0.0197, LR: 0.000819
# Epoch 852/2000, Train Loss: 0.0225, Val Loss: 0.0209, LR: 0.000819
# Epoch 853/2000, Train Loss: 0.0215, Val Loss: 0.0044, LR: 0.000819
# Epoch 854/2000, Train Loss: 0.0190, Val Loss: 0.0088, LR: 0.000819
# Epoch 855/2000, Train Loss: 0.0199, Val Loss: 0.0025, LR: 0.000819
# Epoch 856/2000, Train Loss: 0.0202, Val Loss: 0.0188, LR: 0.000819
# Epoch 857/2000, Train Loss: 0.0186, Val Loss: 0.0105, LR: 0.000819
# Epoch 858/2000, Train Loss: 0.0220, Val Loss: 0.0085, LR: 0.000819
# Epoch 859/2000, Train Loss: 0.0221, Val Loss: 0.0151, LR: 0.000819
# Epoch 860/2000, Train Loss: 0.0204, Val Loss: 0.0129, LR: 0.000819
# Epoch 861/2000, Train Loss: 0.0195, Val Loss: 0.0202, LR: 0.000819
# Epoch 862/2000, Train Loss: 0.0198, Val Loss: 0.0233, LR: 0.000819
# Epoch 863/2000, Train Loss: 0.0209, Val Loss: 0.0176, LR: 0.000819
# Epoch 864/2000, Train Loss: 0.0199, Val Loss: 0.0033, LR: 0.000819
# Epoch 865/2000, Train Loss: 0.0197, Val Loss: 0.0166, LR: 0.000819
# Epoch 866/2000, Train Loss: 0.0207, Val Loss: 0.0155, LR: 0.000819
# Epoch 867/2000, Train Loss: 0.0207, Val Loss: 0.0185, LR: 0.000819
# Epoch 868/2000, Train Loss: 0.0207, Val Loss: 0.0251, LR: 0.000819
# Epoch 869/2000, Train Loss: 0.0224, Val Loss: 0.0200, LR: 0.000819
# Epoch 870/2000, Train Loss: 0.0197, Val Loss: 0.0188, LR: 0.000819
# Epoch 871/2000, Train Loss: 0.0203, Val Loss: 0.0143, LR: 0.000819
# Epoch 872/2000, Train Loss: 0.0205, Val Loss: 0.0168, LR: 0.000819
# Epoch 873/2000, Train Loss: 0.0198, Val Loss: 0.0141, LR: 0.000819
# Epoch 874/2000, Train Loss: 0.0187, Val Loss: 0.0358, LR: 0.000819
# Epoch 875/2000, Train Loss: 0.0206, Val Loss: 0.0333, LR: 0.000819
# Epoch 876/2000, Train Loss: 0.0213, Val Loss: 0.0439, LR: 0.000819
# Epoch 877/2000, Train Loss: 0.0209, Val Loss: 0.0149, LR: 0.000819
# Epoch 878/2000, Train Loss: 0.0208, Val Loss: 0.0118, LR: 0.000819
# Epoch 879/2000, Train Loss: 0.0200, Val Loss: 0.0103, LR: 0.000819
# Epoch 880/2000, Train Loss: 0.0198, Val Loss: 0.0085, LR: 0.000819
# Epoch 881/2000, Train Loss: 0.0191, Val Loss: 0.0159, LR: 0.000819
# Epoch 882/2000, Train Loss: 0.0222, Val Loss: 0.0115, LR: 0.000819
# Epoch 883/2000, Train Loss: 0.0188, Val Loss: 0.0108, LR: 0.000819
# Epoch 884/2000, Train Loss: 0.0202, Val Loss: 0.0136, LR: 0.000819
# Epoch 885/2000, Train Loss: 0.0183, Val Loss: 0.0071, LR: 0.000819
# Epoch 886/2000, Train Loss: 0.0200, Val Loss: 0.0072, LR: 0.000819
# Epoch 887/2000, Train Loss: 0.0204, Val Loss: 0.0145, LR: 0.000819
# Epoch 888/2000, Train Loss: 0.0223, Val Loss: 0.0260, LR: 0.000819
# Epoch 889/2000, Train Loss: 0.0181, Val Loss: 0.0571, LR: 0.000819
# Epoch 890/2000, Train Loss: 0.0207, Val Loss: 0.0196, LR: 0.000819
# Epoch 891/2000, Train Loss: 0.0204, Val Loss: 0.0123, LR: 0.000819
# Epoch 892/2000, Train Loss: 0.0205, Val Loss: 0.0162, LR: 0.000819
# Epoch 893/2000, Train Loss: 0.0202, Val Loss: 0.0112, LR: 0.000819
# Epoch 894/2000, Train Loss: 0.0191, Val Loss: 0.0038, LR: 0.000819
# Epoch 895/2000, Train Loss: 0.0208, Val Loss: 0.0145, LR: 0.000819
# Epoch 896/2000, Train Loss: 0.0200, Val Loss: 0.0320, LR: 0.000819
# Epoch 897/2000, Train Loss: 0.0193, Val Loss: 0.0145, LR: 0.000819
# Epoch 898/2000, Train Loss: 0.0205, Val Loss: 0.0264, LR: 0.000819
# Epoch 899/2000, Train Loss: 0.0196, Val Loss: 0.0267, LR: 0.000819
# Epoch 900/2000, Train Loss: 0.0191, Val Loss: 0.0098, LR: 0.000819
# Epoch 901/2000, Train Loss: 0.0198, Val Loss: 0.0135, LR: 0.000819
# Epoch 902/2000, Train Loss: 0.0185, Val Loss: 0.0152, LR: 0.000819
# Epoch 903/2000, Train Loss: 0.0194, Val Loss: 0.0277, LR: 0.000819
# Epoch 904/2000, Train Loss: 0.0209, Val Loss: 0.0136, LR: 0.000819
# Epoch 905/2000, Train Loss: 0.0215, Val Loss: 0.0198, LR: 0.000819
# Epoch 906/2000, Train Loss: 0.0186, Val Loss: 0.0315, LR: 0.000819
# Epoch 907/2000, Train Loss: 0.0185, Val Loss: 0.0102, LR: 0.000819
# Epoch 908/2000, Train Loss: 0.0206, Val Loss: 0.0278, LR: 0.000819
# Epoch 909/2000, Train Loss: 0.0202, Val Loss: 0.0370, LR: 0.000819
# Epoch 910/2000, Train Loss: 0.0192, Val Loss: 0.0447, LR: 0.000819
# Epoch 911/2000, Train Loss: 0.0209, Val Loss: 0.0338, LR: 0.000819
# Epoch 912/2000, Train Loss: 0.0199, Val Loss: 0.0376, LR: 0.000819
# Epoch 913/2000, Train Loss: 0.0180, Val Loss: 0.0154, LR: 0.000819
# Epoch 914/2000, Train Loss: 0.0191, Val Loss: 0.0062, LR: 0.000819
# Epoch 915/2000, Train Loss: 0.0193, Val Loss: 0.0176, LR: 0.000819
# Epoch 916/2000, Train Loss: 0.0202, Val Loss: 0.0310, LR: 0.000819
# Epoch 917/2000, Train Loss: 0.0222, Val Loss: 0.0412, LR: 0.000819
# Epoch 918/2000, Train Loss: 0.0179, Val Loss: 0.0370, LR: 0.000819
# Epoch 919/2000, Train Loss: 0.0184, Val Loss: 0.0164, LR: 0.000819
# Epoch 920/2000, Train Loss: 0.0189, Val Loss: 0.0144, LR: 0.000819
# Epoch 921/2000, Train Loss: 0.0186, Val Loss: 0.0120, LR: 0.000819
# Epoch 922/2000, Train Loss: 0.0205, Val Loss: 0.0192, LR: 0.000819
# Epoch 923/2000, Train Loss: 0.0199, Val Loss: 0.0084, LR: 0.000819
# Epoch 924/2000, Train Loss: 0.0197, Val Loss: 0.0099, LR: 0.000819
# Epoch 925/2000, Train Loss: 0.0202, Val Loss: 0.0135, LR: 0.000819
# Epoch 926/2000, Train Loss: 0.0195, Val Loss: 0.0169, LR: 0.000819
# Epoch 927/2000, Train Loss: 0.0187, Val Loss: 0.0077, LR: 0.000819
# Epoch 928/2000, Train Loss: 0.0197, Val Loss: 0.0099, LR: 0.000819
# Epoch 929/2000, Train Loss: 0.0172, Val Loss: 0.0026, LR: 0.000819
# Epoch 930/2000, Train Loss: 0.0187, Val Loss: 0.0127, LR: 0.000819
# Epoch 931/2000, Train Loss: 0.0175, Val Loss: 0.0208, LR: 0.000819
# Epoch 932/2000, Train Loss: 0.0186, Val Loss: 0.0087, LR: 0.000819
# Epoch 933/2000, Train Loss: 0.0179, Val Loss: 0.0181, LR: 0.000819
# Epoch 934/2000, Train Loss: 0.0194, Val Loss: 0.0245, LR: 0.000819
# Epoch 935/2000, Train Loss: 0.0178, Val Loss: 0.0191, LR: 0.000819
# Epoch 936/2000, Train Loss: 0.0190, Val Loss: 0.0119, LR: 0.000819
# Epoch 937/2000, Train Loss: 0.0179, Val Loss: 0.0213, LR: 0.000819
# Epoch 938/2000, Train Loss: 0.0184, Val Loss: 0.0232, LR: 0.000819
# Epoch 939/2000, Train Loss: 0.0197, Val Loss: 0.0150, LR: 0.000819
# Epoch 940/2000, Train Loss: 0.0200, Val Loss: 0.0048, LR: 0.000819
# Epoch 941/2000, Train Loss: 0.0195, Val Loss: 0.0077, LR: 0.000819
# Epoch 942/2000, Train Loss: 0.0176, Val Loss: 0.0152, LR: 0.000819
# Epoch 943/2000, Train Loss: 0.0191, Val Loss: 0.0407, LR: 0.000819
# Epoch 944/2000, Train Loss: 0.0199, Val Loss: 0.0233, LR: 0.000819
# Epoch 945/2000, Train Loss: 0.0199, Val Loss: 0.0237, LR: 0.000819
# Epoch 946/2000, Train Loss: 0.0188, Val Loss: 0.0182, LR: 0.000819
# Epoch 947/2000, Train Loss: 0.0182, Val Loss: 0.0205, LR: 0.000819
# Epoch 948/2000, Train Loss: 0.0186, Val Loss: 0.0280, LR: 0.000819
# Epoch 949/2000, Train Loss: 0.0184, Val Loss: 0.0660, LR: 0.000819
# Epoch 950/2000, Train Loss: 0.0196, Val Loss: 0.0106, LR: 0.000819
# Epoch 951/2000, Train Loss: 0.0186, Val Loss: 0.0058, LR: 0.000819
# Epoch 952/2000, Train Loss: 0.0189, Val Loss: 0.0041, LR: 0.000819
# Epoch 953/2000, Train Loss: 0.0189, Val Loss: 0.0037, LR: 0.000819
# Epoch 954/2000, Train Loss: 0.0190, Val Loss: 0.0081, LR: 0.000819
# Epoch 955/2000, Train Loss: 0.0173, Val Loss: 0.0110, LR: 0.000819
# Early stopping triggered after epoch 955. Validation loss did not improve for 100 epochs.
# Training finished!

# %%
# 9. Plotting Loss Curves
plt.figure(figsize=(10, 6)) # Set figure size for better readability
plt.plot(train_losses[200:], label='Train Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.legend() # Show legend to distinguish between train and val loss
plt.grid(True) # Add grid for easier reading
plt.show()    # Display the plot

# %%
# 9. Plotting Loss Curves
plt.figure(figsize=(10, 6)) # Set figure size for better readability
plt.plot(val_losses[200:], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss Curve')
plt.legend() # Show legend to distinguish between train and val loss
plt.grid(True) # Add grid for easier reading
plt.show()    # Display the plot

# %%
# 6. Example Inference (after training)
#    Load a sample histogram and IRF (e.g., from your validation set or a new measurement)
sample_index = 3 # Example index from validation set
sample_histogram = torch.tensor(histograms_val[sample_index], dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) # Add batch and channel dimension
sample_irf = torch.tensor(irfs_val[sample_index], dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) # Add batch and channel dimension

trained_model.eval() # Set model to evaluation mode
with torch.no_grad():
    predicted_optical_properties = trained_model(sample_histogram, sample_irf)

predicted_ups = predicted_optical_properties[0][0].item()
predicted_ua = predicted_optical_properties[0][1].item()
actual_ups = ups_val[sample_index]
actual_ua = ua_val[sample_index]

print(f"Predicted ups: {predicted_ups:.4f}, Actual ups: {actual_ups:.4f}")
print(f"Predicted ua: {predicted_ua:.4f}, Actual ua: {actual_ua:.4f}")
# Out:
# Predicted ups: 1.1670, Actual ups: 1.2685
# Predicted ua: 0.0099, Actual ua: 0.0109

# %%
error_ua = []
error_ups = []
actual_uas = []
actual_upss = []

for i in range(len(histograms_val)):
    sample_histogram = torch.tensor(histograms_val[i], dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) # Add batch and channel dimension
    sample_irf = torch.tensor(irfs_val[i], dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device) # Add batch and channel dimension

    trained_model.eval() # Set model to evaluation mode
    with torch.no_grad():
        predicted_optical_properties = trained_model(sample_histogram, sample_irf)

    predicted_ups = predicted_optical_properties[0][0].item()
    predicted_ua = predicted_optical_properties[0][1].item()
    actual_ups = ups_val[i]
    actual_ua = ua_val[i]

    actual_uas.append(actual_ua)
    actual_upss.append(actual_ups)

    error_ua.append(abs((actual_ua - predicted_ua)/actual_ua)*100)
    error_ups.append(abs((actual_ups - predicted_ups)/actual_ups)*100)
    

print("Mean error in ups: ", np.mean(error_ups))
print("Mean error in ua: ", np.mean(error_ua))

plt.plot(error_ua, label='Error in ua')
plt.plot(error_ups, label='Error in ups')
# Out:
# Mean error in ups:  11.650340102681039
# Mean error in ua:  16.87475671544352

# %%
plt.figure(figsize=(10, 6))
plt.scatter(actual_uas, error_ua, alpha=0.6)
plt.xlabel('Actual ua')
plt.ylabel('Error in ua (%)')
plt.title('Error in ua vs Actual ua')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(actual_upss, error_ups, alpha=0.6)
plt.xlabel('Actual ups')
plt.ylabel('Error in ups (%)')
plt.title('Error in ups vs Actual ups')
plt.grid(True)
plt.show()

# %%
# 7. Save the trained model (optional)
torch.save(trained_model.state_dict(), 'optical_properties_estimator.pth')
